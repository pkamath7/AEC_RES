# %%
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import os
import numpy as np
import torch.nn as nn
import pandas as pd
import librosa
import librosa.display
from torch.utils.data import sampler
import torch.optim as optim
import json
import cv2
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
from torchinfo import summary
from IPython.display import Audio
import IPython.display as ipd
import soundfile as sd
import padasip as dsp

# %%
class ICASSPDatasetHelper():
    #initialization 
    def __init__(self):
        self.sample_rate=8000
        fft_len=40
        hop_len=10
        self.dir= "./icassp_LUT.json"
        openfile=open(self.dir, "r")
        self.dataset_dict= json.load(openfile)
        indx=1
        self.keys={}
        for key  in self.dataset_dict.keys():
            self.keys[indx]=key
            indx+=1

        self.num_files_per_category=len(self.dataset_dict["echo_signal"].keys())

    #get the indexed file and sample rate
    def get_indxd_file(self,indx,src):
        category=self.keys[src]
        #load magnitude spectrum
        data=abs(np.load(self.dataset_dict[category][str(indx)]))
        Id= self.dataset_dict[category][str(indx)].split("/")[-1].split('.')[0]
        return (data,Id)

    #get the indexed file and sample rate
    def get_indxd_filestft(self,indx,src):
        category=self.keys[src]
        #load magnitude spectrum
        data=np.load(self.dataset_dict[category][str(indx)])
        Id= self.dataset_dict[category][str(indx)].split("/")[-1].split('.')[0]
        return (data,Id)

# %%
class ICASSP(Dataset):
    def __init__(self):
        #super().__init__(self)
        self.daps= ICASSPDatasetHelper()

    def __getitem__(self, index):
        mic,id=self.daps.get_indxd_file(index,2)
        fend,id=self.daps.get_indxd_file(index,3)
        nend,id=self.daps.get_indxd_file(index,4)
        return (mic,fend,nend)

    def __len__(self):
        
        #print (self.daps.num_files_per_category)
        return self.daps.num_files_per_category

# %%
dataset_train = ICASSP()
print(dataset_train.__len__())
print(dataset_train.daps.keys)
# Out:
# 62000
# {1: 'echo_signal', 2: 'nearend_mic_signal', 3: 'farend_speech', 4: 'nearend_speech'}

# %%
dtype = torch.float32 # we will be using float throughout this tutorial
USE_GPU = True
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print(device)
# Out:
# cuda

# %%
def flatten(x):
    N = x.shape[0] # read in N, C, H, W
    return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %%
NUM_TRAIN=30000
NUM_VAL=10000
NUM_TEST=5000
print_every = 100
dataset_train = ICASSP()
batch_size=16
loader_train = DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_TRAIN)))
loader_val= DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_TRAIN,NUM_VAL+NUM_TRAIN)))
loader_test = DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_VAL+NUM_TRAIN, NUM_VAL+NUM_TRAIN+NUM_TEST)))

helper= ICASSPDatasetHelper()

# %%
print(dataset_train.daps.keys)
# Out:
# {1: 'echo_signal', 2: 'nearend_mic_signal', 3: 'farend_speech', 4: 'nearend_speech'}

# %%
#Create Model classes
# create a class for linear layers 
class DenseLayer(nn.Module):
    def __init__(self,input_size,output_size,dropOut_p):
        super().__init__()
        self.dense=nn.Linear(input_size,output_size,bias=True)
        self.activation=nn.Tanh()
        self.dropOut=nn.Dropout(p=dropOut_p,inplace=False)
    
    def forward(self,x):
        y=self.dense(x)
        y=self.activation(y)
        y=self.dropOut(y)
        return y

#class for convolutional layers
class ConvLayer(nn.Module):
    def __init__(self,in_ch,out_ch,kernel_size,stride,padding,dropOut_p):
        super().__init__()
        self.conv=nn.Conv2d(in_ch,out_ch,kernel_size, stride=stride,padding=padding)
        self.activation=nn.ReLU()
        self.dropOut=nn.Dropout2d(p=dropOut_p,inplace=False)
    
    def forward(self,x):
        y=self.conv(x)
        y=self.activation(y)
        y=self.dropOut(y)

        return y

#RNN model for Residual echo suppression
class LSTMNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, fclayer_dim, output_dim, num_layers,dropout_prob):
        super().__init__()
        # Defining the number of layers and the nodes in each layer
        self.layer_dim=num_layers
        self.hidden_dim=hidden_dim
        self.rnn = nn.LSTM(
            fclayer_dim, hidden_dim, num_layers, batch_first=True
        )
        self.tanh=nn.Tanh()
        self.fc1= nn.Linear(input_dim,fclayer_dim)
        self.fc2= nn.Linear(hidden_dim,output_dim)
        self.sig=nn.Sigmoid()


    def forward(self, x):
        
        y= self.fc1(x)

        y= self.tanh(y)
        # Initializing hidden state for first input with zeros
        h0 = torch.zeros(self.layer_dim, y.size(0), self.hidden_dim).requires_grad_()

        # Forward propagation by passing in the input and hidden state into the model
        out, h0 = self.rnn(y)

        # Reshaping the outputs in the shape of (batch_size, seq_length, hidden_size)
        # so that it can fit into the fully connected layer
        #out = out[:, -1, :]
        out=self.tanh(out)
        # Convert the final state to our desired output shape (batch_size, output_dim)
        out = self.fc2(out)
        out = self.sig(out)
        return out

# %%
#SNR loss where yhat is average power spectrum of de-nonlinearised/denoised signal/ clean signal power 
def Loss_MSE(yhat,y,lossfn):
    target = torch.ones(1).to(device=device)
    #yhat=yhat.squeeze(0)
    #y=y.squeeze(0)
    #loss=lossfn(yhat,y,target)
    loss=lossfn(yhat,y)
    return loss

# %%
def check_accuracy(loader, model,lossfn):
    print('Checking accuracy on validation set')
    model.eval()  # set model to evaluation mode
    mse=0
    with torch.no_grad():
        for mic, fend, nend in loader:

            x=torch.concat((mic,fend),1)
            #print(x.shape)          
            #iterate over each stft frame 
            x=x.to(device=device, dtype=dtype)
            mic=mic.to(device=device, dtype=dtype)
            nend=nend.to(device=device, dtype=dtype)
            x=torch.permute(x, (0, 2, 1))
            y=torch.permute(nend, (0, 2, 1))
            mic=torch.permute(mic, (0, 2, 1))
            pw_x=x*x
            # Forward pass: compute scores and loss
            mask = model(pw_x)

            yhat= mask*mic
            #yhat=yhat[:,:,:,-1]
            #y=y[:,:,:,-1]
            mse+= Loss_MSE(y,yhat,lossfn)
        mse = mse / len(loader)
        print("Validation loss is", mse.cpu().numpy())
        return  mse.cpu().numpy()

# %%
print_every=1
def train_model(model, optimizer, scheduler ,epochs=1):
    """
    Train a model on DAPS.
    
    Inputs:
    - model_fn: A Python function that performs the forward pass of the model.
      It should have the signature scores = model_fn(x, params) where x is a
      PyTorch Tensor of image data, params is a list of PyTorch Tensors giving
      model weights, and scores is a PyTorch Tensor of shape (N, C) giving
      scores for the elements in x.
    - params: List of PyTorch Tensors giving weights for the model
    - learning_rate: Python scalar giving the learning rate to use for SGD
    
    Returns: val loss and train loss
    """
    val_loss=[]
    train_loss=[]
    #lossfn=nn.CosineEmbeddingLoss(margin=0,reduction="mean")
    lossfn=nn.MSELoss()
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        running_loss = 0
        for t, (mic, fend,nend) in enumerate(loader_train):
            
           
            x=torch.concat((mic,fend),1)
            #print(x.shape)          
            #iterate over each stft frame 
            x=x.to(device=device, dtype=dtype)
            mic=mic.to(device=device, dtype=dtype)
            nend=nend.to(device=device, dtype=dtype)
            x=torch.permute(x, (0, 2, 1))
            y=torch.permute(nend, (0, 2, 1))
            mic=torch.permute(mic, (0, 2, 1))
            pw_x=x*x
            # Forward pass: compute scores and loss

            mask = model(pw_x)
            #print(mask.shape)
            yhat= mask*mic

            #yhat=yhat[:,:,:,-1]
            #y=y[:,:,:,-1]

            loss = Loss_MSE(yhat, y, lossfn)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            # Update parameters. We don't want to backpropagate through the
            running_loss += loss.item()
            

        if t % print_every == 0:
            print('Epoch %d, Iteration %d, loss = %.8f' % (e, t, (running_loss/len(loader_train))))
            train_loss.append(running_loss/len(loader_train))
            #check_accuracy_part2(loader_val, model_fn, params)
            
        vloss=check_accuracy(loader_val,model,lossfn)
        model.train()
        val_loss.append(vloss)
        scheduler.step(loss)
    return (train_loss,val_loss)

# %%
learning_rate = 1e-3
nfft_len=318
hop_size=nfft_len//4
specdims=(160,32)
model = LSTMNet(input_dim=specdims[0]*2, hidden_dim=25, fclayer_dim=25, output_dim=specdims[0], num_layers=1,dropout_prob=0.0)
# you can use Nesterov momentum in optim.SGD
#optimizer = optim.SGD(model.parameters(), lr=learning_rate,
#                     momentum=0.9, nesterov=True)
# you can use Nesterov momentum in optim.SGD
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

# %%
batch_size = batch_size
summary(model, input_size=(batch_size,specdims[1], specdims[0]*2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LSTMNet                                  --                        --
# ├─Linear: 1-1                            [16, 32, 25]              8,025
# ├─Tanh: 1-2                              [16, 32, 25]              --
# ├─LSTM: 1-3                              [16, 32, 25]              5,200
# ├─Tanh: 1-4                              [16, 32, 25]              --
# ├─Linear: 1-5                            [16, 32, 160]             4,160
# ├─Sigmoid: 1-6                           [16, 32, 160]             --
# ==========================================================================================
# Total params: 17,385
# Trainable params: 17,385
# Non-trainable params: 0
# Total mult-adds (M): 2.86
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 0.86
# Params size (MB): 0.07
# Estimated Total Size (MB): 1.59
# ==========================================================================================

# %%
(train_loss,val_loss)=train_model(model, optimizer, scheduler,200)
# Out:
# Epoch 0, Iteration 1874, loss = 0.57408185
# Checking accuracy on validation set
# Validation loss is 0.5391935
# Epoch 1, Iteration 1874, loss = 0.50774887
# Checking accuracy on validation set
# Validation loss is 0.5050898
# Epoch 2, Iteration 1874, loss = 0.48874894
# Checking accuracy on validation set
# Validation loss is 0.49076316
# Epoch 3, Iteration 1874, loss = 0.47873781
# Checking accuracy on validation set
# Validation loss is 0.48447567
# Epoch 4, Iteration 1874, loss = 0.46976410
# Checking accuracy on validation set
# Validation loss is 0.46690843
# Epoch 5, Iteration 1874, loss = 0.46262126
# Checking accuracy on validation set
# Validation loss is 0.46289346
# Epoch 6, Iteration 1874, loss = 0.45723784
# Checking accuracy on validation set
# Validation loss is 0.45897484
# Epoch 7, Iteration 1874, loss = 0.45202500
# Checking accuracy on validation set
# Validation loss is 0.45151728
# Epoch 8, Iteration 1874, loss = 0.44788232
# Checking accuracy on validation set
# Validation loss is 0.4472501
# Epoch 9, Iteration 1874, loss = 0.44433180
# Checking accuracy on validation set
# Validation loss is 0.44554275
# Epoch 10, Iteration 1874, loss = 0.43960220
# Checking accuracy on validation set
# Validation loss is 0.4519851
# Epoch 11, Iteration 1874, loss = 0.43945381
# Checking accuracy on validation set
# Validation loss is 0.44510105
# Epoch 12, Iteration 1874, loss = 0.43651810
# Checking accuracy on validation set
# Validation loss is 0.43874487
# Epoch 13, Iteration 1874, loss = 0.43334056
# Checking accuracy on validation set
# Validation loss is 0.43774173
# Epoch 14, Iteration 1874, loss = 0.43164821
# Checking accuracy on validation set
# Validation loss is 0.43289033
# Epoch 15, Iteration 1874, loss = 0.42806018
# Checking accuracy on validation set
# Validation loss is 0.42993462
# Epoch 16, Iteration 1874, loss = 0.42539732
# Checking accuracy on validation set
# Validation loss is 0.4316912
# Epoch 17, Iteration 1874, loss = 0.42572358
# Checking accuracy on validation set
# Validation loss is 0.43565243
# Epoch 18, Iteration 1874, loss = 0.42442059
# Checking accuracy on validation set
# Validation loss is 0.4332063
# Epoch 19, Iteration 1874, loss = 0.42203114
# Checking accuracy on validation set
# Validation loss is 0.4305248
# Epoch 20, Iteration 1874, loss = 0.41351165
# Checking accuracy on validation set
# Validation loss is 0.40954012
# Epoch 21, Iteration 1874, loss = 0.40770230
# Checking accuracy on validation set
# Validation loss is 0.40636456
# Epoch 22, Iteration 1874, loss = 0.40548907
# Checking accuracy on validation set
# Validation loss is 0.4038449
# Epoch 23, Iteration 1874, loss = 0.40361455
# Checking accuracy on validation set
# Validation loss is 0.4026144
# Epoch 24, Iteration 1874, loss = 0.40218077
# Checking accuracy on validation set
# Validation loss is 0.4010601
# Epoch 25, Iteration 1874, loss = 0.40093727
# Checking accuracy on validation set
# Validation loss is 0.3998845
# Epoch 26, Iteration 1874, loss = 0.39973909
# Checking accuracy on validation set
# Validation loss is 0.39910072
# Epoch 27, Iteration 1874, loss = 0.39880862
# Checking accuracy on validation set
# Validation loss is 0.3980089
# Epoch 28, Iteration 1874, loss = 0.39792219
# Checking accuracy on validation set
# Validation loss is 0.39715633
# Epoch 29, Iteration 1874, loss = 0.39705112
# Checking accuracy on validation set
# Validation loss is 0.3964197
# Epoch 30, Iteration 1874, loss = 0.39648465
# Checking accuracy on validation set
# Validation loss is 0.39561114
# Epoch 31, Iteration 1874, loss = 0.39474941
# Checking accuracy on validation set
# Validation loss is 0.39484683
# Epoch 32, Iteration 1874, loss = 0.39422255
# Checking accuracy on validation set
# Validation loss is 0.39441344
# Epoch 33, Iteration 1874, loss = 0.39393563
# Checking accuracy on validation set
# Validation loss is 0.3940968
# Epoch 34, Iteration 1874, loss = 0.39372473
# Checking accuracy on validation set
# Validation loss is 0.3938621
# Epoch 35, Iteration 1874, loss = 0.39355717
# Checking accuracy on validation set
# Validation loss is 0.39366192
# Epoch 36, Iteration 1874, loss = 0.39340830
# Checking accuracy on validation set
# Validation loss is 0.39349183
# Epoch 37, Iteration 1874, loss = 0.39328153
# Checking accuracy on validation set
# Validation loss is 0.3933378
# Epoch 38, Iteration 1874, loss = 0.39316587
# Checking accuracy on validation set
# Validation loss is 0.39319563
# Epoch 39, Iteration 1874, loss = 0.39305407
# Checking accuracy on validation set
# Validation loss is 0.393071
# Epoch 40, Iteration 1874, loss = 0.39295275
# Checking accuracy on validation set
# Validation loss is 0.392955
# Epoch 41, Iteration 1874, loss = 0.39285521
# Checking accuracy on validation set
# Validation loss is 0.39284486
# Epoch 42, Iteration 1874, loss = 0.39256346
# Checking accuracy on validation set
# Validation loss is 0.39281505
# Epoch 43, Iteration 1874, loss = 0.39254776
# Checking accuracy on validation set
# Validation loss is 0.39278913
# Epoch 44, Iteration 1874, loss = 0.39253398
# Checking accuracy on validation set
# Validation loss is 0.39276603
# Epoch 45, Iteration 1874, loss = 0.39252156
# Checking accuracy on validation set
# Validation loss is 0.39274573
# Epoch 46, Iteration 1874, loss = 0.39251006
# Checking accuracy on validation set
# Validation loss is 0.39272657
# Epoch 47, Iteration 1874, loss = 0.39249920
# Checking accuracy on validation set
# Validation loss is 0.3927088
# Epoch 48, Iteration 1874, loss = 0.39248878
# Checking accuracy on validation set
# Validation loss is 0.3926924
# Epoch 49, Iteration 1874, loss = 0.39247870
# Checking accuracy on validation set
# Validation loss is 0.39267686
# Epoch 50, Iteration 1874, loss = 0.39246886
# Checking accuracy on validation set
# Validation loss is 0.39266178
# Epoch 51, Iteration 1874, loss = 0.39245921
# Checking accuracy on validation set
# Validation loss is 0.39264736
# Epoch 52, Iteration 1874, loss = 0.39244971
# Checking accuracy on validation set
# Validation loss is 0.39263377
# Epoch 53, Iteration 1874, loss = 0.39241695
# Checking accuracy on validation set
# Validation loss is 0.39263237
# Epoch 54, Iteration 1874, loss = 0.39241603
# Checking accuracy on validation set
# Validation loss is 0.39263085
# Epoch 55, Iteration 1874, loss = 0.39241511
# Checking accuracy on validation set
# Validation loss is 0.39262944
# Epoch 56, Iteration 1874, loss = 0.39241419
# Checking accuracy on validation set
# Validation loss is 0.39262798
# Epoch 57, Iteration 1874, loss = 0.39241328
# Checking accuracy on validation set
# Validation loss is 0.39262623
# Epoch 58, Iteration 1874, loss = 0.39241236
# Checking accuracy on validation set
# Validation loss is 0.39262488
# Epoch 59, Iteration 1874, loss = 0.39241145
# Checking accuracy on validation set
# Validation loss is 0.39262348
# Epoch 60, Iteration 1874, loss = 0.39241054
# Checking accuracy on validation set
# Validation loss is 0.3926218
# Epoch 61, Iteration 1874, loss = 0.39240963
# Checking accuracy on validation set
# Validation loss is 0.39262035
# Epoch 62, Iteration 1874, loss = 0.39240872
# Checking accuracy on validation set
# Validation loss is 0.39261916
# Epoch 63, Iteration 1874, loss = 0.39240782
# Checking accuracy on validation set
# Validation loss is 0.3926178
# Epoch 64, Iteration 1874, loss = 0.39240447
# Checking accuracy on validation set
# Validation loss is 0.3926177
# Epoch 65, Iteration 1874, loss = 0.39240441
# Checking accuracy on validation set
# Validation loss is 0.39261755
# Epoch 66, Iteration 1874, loss = 0.39240436
# Checking accuracy on validation set
# Validation loss is 0.39261743
# Epoch 67, Iteration 1874, loss = 0.39240431
# Checking accuracy on validation set
# Validation loss is 0.39261734
# Epoch 68, Iteration 1874, loss = 0.39240426
# Checking accuracy on validation set
# Validation loss is 0.3926172
# Epoch 69, Iteration 1874, loss = 0.39240421
# Checking accuracy on validation set
# Validation loss is 0.39261714
# Epoch 70, Iteration 1874, loss = 0.39240415
# Checking accuracy on validation set
# Validation loss is 0.39261702
# Epoch 71, Iteration 1874, loss = 0.39240410
# Checking accuracy on validation set
# Validation loss is 0.39261693
# Epoch 72, Iteration 1874, loss = 0.39240405
# Checking accuracy on validation set
# Validation loss is 0.39261684
# Epoch 73, Iteration 1874, loss = 0.39240399
# Checking accuracy on validation set
# Validation loss is 0.39261675
# Epoch 74, Iteration 1874, loss = 0.39240394
# Checking accuracy on validation set
# Validation loss is 0.3926167
# Epoch 75, Iteration 1874, loss = 0.39240389
# Checking accuracy on validation set
# Validation loss is 0.39261663
# Epoch 76, Iteration 1874, loss = 0.39240384
# Checking accuracy on validation set
# Validation loss is 0.39261663
# Epoch 77, Iteration 1874, loss = 0.39240379
# Checking accuracy on validation set
# Validation loss is 0.3926166
# Epoch 78, Iteration 1874, loss = 0.39240373
# Checking accuracy on validation set
# Validation loss is 0.3926166
# Epoch 79, Iteration 1874, loss = 0.39240368
# Checking accuracy on validation set
# Validation loss is 0.3926166
# Epoch 80, Iteration 1874, loss = 0.39240363
# Checking accuracy on validation set
# Validation loss is 0.39261642
# Epoch 81, Iteration 1874, loss = 0.39240358
# Checking accuracy on validation set
# Validation loss is 0.39261636
# Epoch 82, Iteration 1874, loss = 0.39240352
# Checking accuracy on validation set
# Validation loss is 0.39261636
# Epoch 83, Iteration 1874, loss = 0.39240347
# Checking accuracy on validation set
# Validation loss is 0.39261633
# Epoch 84, Iteration 1874, loss = 0.39240342
# Checking accuracy on validation set
# Validation loss is 0.39261633
# Epoch 85, Iteration 1874, loss = 0.39240337
# Checking accuracy on validation set
# Validation loss is 0.3926162
# Epoch 86, Iteration 1874, loss = 0.39240331
# Checking accuracy on validation set
# Validation loss is 0.39261618
# Epoch 87, Iteration 1874, loss = 0.39240326
# Checking accuracy on validation set
# Validation loss is 0.3926161
# Epoch 88, Iteration 1874, loss = 0.39240321
# Checking accuracy on validation set
# Validation loss is 0.39261606
# Epoch 89, Iteration 1874, loss = 0.39240316
# Checking accuracy on validation set
# Validation loss is 0.392616
# Epoch 90, Iteration 1874, loss = 0.39240311
# Checking accuracy on validation set
# Validation loss is 0.39261588
# Epoch 91, Iteration 1874, loss = 0.39240306
# Checking accuracy on validation set
# Validation loss is 0.39261582
# Epoch 92, Iteration 1874, loss = 0.39240300
# Checking accuracy on validation set
# Validation loss is 0.39261565
# Epoch 93, Iteration 1874, loss = 0.39240295
# Checking accuracy on validation set
# Validation loss is 0.3926155
# Epoch 94, Iteration 1874, loss = 0.39240290
# Checking accuracy on validation set
# Validation loss is 0.39261544
# Epoch 95, Iteration 1874, loss = 0.39240285
# Checking accuracy on validation set
# Validation loss is 0.39261535
# Epoch 96, Iteration 1874, loss = 0.39240279
# Checking accuracy on validation set
# Validation loss is 0.3926153
# Epoch 97, Iteration 1874, loss = 0.39240274
# Checking accuracy on validation set
# Validation loss is 0.39261517
# Epoch 98, Iteration 1874, loss = 0.39240269
# Checking accuracy on validation set
# Validation loss is 0.3926151
# Epoch 99, Iteration 1874, loss = 0.39240264
# Checking accuracy on validation set
# Validation loss is 0.392615
# Epoch 100, Iteration 1874, loss = 0.39240259
# Checking accuracy on validation set
# Validation loss is 0.39261496
# Epoch 101, Iteration 1874, loss = 0.39240254
# Checking accuracy on validation set
# Validation loss is 0.39261487
# Epoch 102, Iteration 1874, loss = 0.39240248
# Checking accuracy on validation set
# Validation loss is 0.39261487
# Epoch 103, Iteration 1874, loss = 0.39240243
# Checking accuracy on validation set
# Validation loss is 0.3926148
# Epoch 104, Iteration 1874, loss = 0.39240238
# Checking accuracy on validation set
# Validation loss is 0.39261487
# Epoch 105, Iteration 1874, loss = 0.39240233
# Checking accuracy on validation set
# Validation loss is 0.39261472
# Epoch 106, Iteration 1874, loss = 0.39240228
# Checking accuracy on validation set
# Validation loss is 0.39261472
# Epoch 107, Iteration 1874, loss = 0.39240222
# Checking accuracy on validation set
# Validation loss is 0.39261472
# Epoch 108, Iteration 1874, loss = 0.39240217
# Checking accuracy on validation set
# Validation loss is 0.39261463
# Epoch 109, Iteration 1874, loss = 0.39240212
# Checking accuracy on validation set
# Validation loss is 0.3926145
# Epoch 110, Iteration 1874, loss = 0.39240207
# Checking accuracy on validation set
# Validation loss is 0.39261448
# Epoch 111, Iteration 1874, loss = 0.39240202
# Checking accuracy on validation set
# Validation loss is 0.39261433
# Epoch 112, Iteration 1874, loss = 0.39240197
# Checking accuracy on validation set
# Validation loss is 0.39261425
# Epoch 113, Iteration 1874, loss = 0.39240192
# Checking accuracy on validation set
# Validation loss is 0.39261422
# Epoch 114, Iteration 1874, loss = 0.39240187
# Checking accuracy on validation set
# Validation loss is 0.3926142
# Epoch 115, Iteration 1874, loss = 0.39240181
# Checking accuracy on validation set
# Validation loss is 0.39261413
# Epoch 116, Iteration 1874, loss = 0.39240176
# Checking accuracy on validation set
# Validation loss is 0.3926139
# Epoch 117, Iteration 1874, loss = 0.39240171
# Checking accuracy on validation set
# Validation loss is 0.3926139
# Epoch 118, Iteration 1874, loss = 0.39240166
# Checking accuracy on validation set
# Validation loss is 0.3926138
# Epoch 119, Iteration 1874, loss = 0.39240161
# Checking accuracy on validation set
# Validation loss is 0.39261374
# Epoch 120, Iteration 1874, loss = 0.39240156
# Checking accuracy on validation set
# Validation loss is 0.39261368
# Epoch 121, Iteration 1874, loss = 0.39240150
# Checking accuracy on validation set
# Validation loss is 0.39261356
# Epoch 122, Iteration 1874, loss = 0.39240145
# Checking accuracy on validation set
# Validation loss is 0.39261365
# Epoch 123, Iteration 1874, loss = 0.39240140
# Checking accuracy on validation set
# Validation loss is 0.39261362
# Epoch 124, Iteration 1874, loss = 0.39240135
# Checking accuracy on validation set
# Validation loss is 0.39261356
# Epoch 125, Iteration 1874, loss = 0.39240130
# Checking accuracy on validation set
# Validation loss is 0.39261353
# Epoch 126, Iteration 1874, loss = 0.39240125
# Checking accuracy on validation set
# Validation loss is 0.39261347
# Epoch 127, Iteration 1874, loss = 0.39240120
# Checking accuracy on validation set
# Validation loss is 0.39261338
# Epoch 128, Iteration 1874, loss = 0.39240114
# Checking accuracy on validation set
# Validation loss is 0.39261344
# Epoch 129, Iteration 1874, loss = 0.39240109
# Checking accuracy on validation set
# Validation loss is 0.39261338
# Epoch 130, Iteration 1874, loss = 0.39240104
# Checking accuracy on validation set
# Validation loss is 0.39261335
# Epoch 131, Iteration 1874, loss = 0.39240099
# Checking accuracy on validation set
# Validation loss is 0.39261317
# Epoch 132, Iteration 1874, loss = 0.39240094
# Checking accuracy on validation set
# Validation loss is 0.3926131
# Epoch 133, Iteration 1874, loss = 0.39240089
# Checking accuracy on validation set
# Validation loss is 0.39261305
# Epoch 134, Iteration 1874, loss = 0.39240084
# Checking accuracy on validation set
# Validation loss is 0.39261293
# Epoch 135, Iteration 1874, loss = 0.39240079
# Checking accuracy on validation set
# Validation loss is 0.39261287
# Epoch 136, Iteration 1874, loss = 0.39240074
# Checking accuracy on validation set
# Validation loss is 0.3926127
# Epoch 137, Iteration 1874, loss = 0.39240069
# Checking accuracy on validation set
# Validation loss is 0.3926126
# Epoch 138, Iteration 1874, loss = 0.39240063
# Checking accuracy on validation set
# Validation loss is 0.39261258
# Epoch 139, Iteration 1874, loss = 0.39240058
# Checking accuracy on validation set
# Validation loss is 0.39261243
# Epoch 140, Iteration 1874, loss = 0.39240053
# Checking accuracy on validation set
# Validation loss is 0.3926123
# Epoch 141, Iteration 1874, loss = 0.39240048
# Checking accuracy on validation set
# Validation loss is 0.3926121
# Epoch 142, Iteration 1874, loss = 0.39240043
# Checking accuracy on validation set
# Validation loss is 0.39261207
# Epoch 143, Iteration 1874, loss = 0.39240038
# Checking accuracy on validation set
# Validation loss is 0.39261204
# Epoch 144, Iteration 1874, loss = 0.39240033
# Checking accuracy on validation set
# Validation loss is 0.39261195
# Epoch 145, Iteration 1874, loss = 0.39240028
# Checking accuracy on validation set
# Validation loss is 0.392612
# Epoch 146, Iteration 1874, loss = 0.39240023
# Checking accuracy on validation set
# Validation loss is 0.39261198
# Epoch 147, Iteration 1874, loss = 0.39240018
# Checking accuracy on validation set
# Validation loss is 0.39261195
# Epoch 148, Iteration 1874, loss = 0.39240012
# Checking accuracy on validation set
# Validation loss is 0.39261192
# Epoch 149, Iteration 1874, loss = 0.39240007
# Checking accuracy on validation set
# Validation loss is 0.39261177
# Epoch 150, Iteration 1874, loss = 0.39240002
# Checking accuracy on validation set
# Validation loss is 0.3926117
# Epoch 151, Iteration 1874, loss = 0.39239997
# Checking accuracy on validation set
# Validation loss is 0.39261162
# Epoch 152, Iteration 1874, loss = 0.39239992
# Checking accuracy on validation set
# Validation loss is 0.39261165
# Epoch 153, Iteration 1874, loss = 0.39239987
# Checking accuracy on validation set
# Validation loss is 0.39261162
# Epoch 154, Iteration 1874, loss = 0.39239982
# Checking accuracy on validation set
# Validation loss is 0.3926116
# Epoch 155, Iteration 1874, loss = 0.39239977
# Checking accuracy on validation set
# Validation loss is 0.3926115
# Epoch 156, Iteration 1874, loss = 0.39239972
# Checking accuracy on validation set
# Validation loss is 0.3926114
# Epoch 157, Iteration 1874, loss = 0.39239967
# Checking accuracy on validation set
# Validation loss is 0.39261115
# Epoch 158, Iteration 1874, loss = 0.39239962
# Checking accuracy on validation set
# Validation loss is 0.39261106
# Epoch 159, Iteration 1874, loss = 0.39239957
# Checking accuracy on validation set
# Validation loss is 0.392611
# Epoch 160, Iteration 1874, loss = 0.39239952
# Checking accuracy on validation set
# Validation loss is 0.39261085
# Epoch 161, Iteration 1874, loss = 0.39239947
# Checking accuracy on validation set
# Validation loss is 0.39261073
# Epoch 162, Iteration 1874, loss = 0.39239941
# Checking accuracy on validation set
# Validation loss is 0.39261076
# Epoch 163, Iteration 1874, loss = 0.39239936
# Checking accuracy on validation set
# Validation loss is 0.39261067
# Epoch 164, Iteration 1874, loss = 0.39239931
# Checking accuracy on validation set
# Validation loss is 0.3926105
# Epoch 165, Iteration 1874, loss = 0.39239926
# Checking accuracy on validation set
# Validation loss is 0.39261046
# Epoch 166, Iteration 1874, loss = 0.39239921
# Checking accuracy on validation set
# Validation loss is 0.3926103
# Epoch 167, Iteration 1874, loss = 0.39239916
# Checking accuracy on validation set
# Validation loss is 0.39261043
# Epoch 168, Iteration 1874, loss = 0.39239911
# Checking accuracy on validation set
# Validation loss is 0.39261037
# Epoch 169, Iteration 1874, loss = 0.39239906
# Checking accuracy on validation set
# Validation loss is 0.39261022
# Epoch 170, Iteration 1874, loss = 0.39239901
# Checking accuracy on validation set
# Validation loss is 0.39261007
# Epoch 171, Iteration 1874, loss = 0.39239896
# Checking accuracy on validation set
# Validation loss is 0.39260998
# Epoch 172, Iteration 1874, loss = 0.39239891
# Checking accuracy on validation set
# Validation loss is 0.39261
# Epoch 173, Iteration 1874, loss = 0.39239886
# Checking accuracy on validation set
# Validation loss is 0.39260983
# Epoch 174, Iteration 1874, loss = 0.39239881
# Checking accuracy on validation set
# Validation loss is 0.39260986
# Epoch 175, Iteration 1874, loss = 0.39239876
# Checking accuracy on validation set
# Validation loss is 0.39260972
# Epoch 176, Iteration 1874, loss = 0.39239871
# Checking accuracy on validation set
# Validation loss is 0.39260966
# Epoch 177, Iteration 1874, loss = 0.39239866
# Checking accuracy on validation set
# Validation loss is 0.3926096
# Epoch 178, Iteration 1874, loss = 0.39239861
# Checking accuracy on validation set
# Validation loss is 0.39260948
# Epoch 179, Iteration 1874, loss = 0.39239856
# Checking accuracy on validation set
# Validation loss is 0.3926093
# Epoch 180, Iteration 1874, loss = 0.39239851
# Checking accuracy on validation set
# Validation loss is 0.39260927
# Epoch 181, Iteration 1874, loss = 0.39239846
# Checking accuracy on validation set
# Validation loss is 0.39260936
# Epoch 182, Iteration 1874, loss = 0.39239841
# Checking accuracy on validation set
# Validation loss is 0.3926093
# Epoch 183, Iteration 1874, loss = 0.39239836
# Checking accuracy on validation set
# Validation loss is 0.3926092
# Epoch 184, Iteration 1874, loss = 0.39239831
# Checking accuracy on validation set
# Validation loss is 0.39260915
# Epoch 185, Iteration 1874, loss = 0.39239826
# Checking accuracy on validation set
# Validation loss is 0.3926092
# Epoch 186, Iteration 1874, loss = 0.39239821
# Checking accuracy on validation set
# Validation loss is 0.39260915
# Epoch 187, Iteration 1874, loss = 0.39239816
# Checking accuracy on validation set
# Validation loss is 0.3926092
# Epoch 188, Iteration 1874, loss = 0.39239811
# Checking accuracy on validation set
# Validation loss is 0.3926091
# Epoch 189, Iteration 1874, loss = 0.39239806
# Checking accuracy on validation set
# Validation loss is 0.39260897
# Epoch 190, Iteration 1874, loss = 0.39239801
# Checking accuracy on validation set
# Validation loss is 0.39260885
# Epoch 191, Iteration 1874, loss = 0.39239796
# Checking accuracy on validation set
# Validation loss is 0.39260888
# Epoch 192, Iteration 1874, loss = 0.39239791
# Checking accuracy on validation set
# Validation loss is 0.3926087
# Epoch 193, Iteration 1874, loss = 0.39239786
# Checking accuracy on validation set
# Validation loss is 0.3926086
# Epoch 194, Iteration 1874, loss = 0.39239781
# Checking accuracy on validation set
# Validation loss is 0.3926086
# Epoch 195, Iteration 1874, loss = 0.39239776
# Checking accuracy on validation set
# Validation loss is 0.3926085
# Epoch 196, Iteration 1874, loss = 0.39239771
# Checking accuracy on validation set
# Validation loss is 0.39260837
# Epoch 197, Iteration 1874, loss = 0.39239766
# Checking accuracy on validation set
# Validation loss is 0.39260834
# Epoch 198, Iteration 1874, loss = 0.39239761
# Checking accuracy on validation set
# Validation loss is 0.39260826
# Epoch 199, Iteration 1874, loss = 0.39239756
# Checking accuracy on validation set
# Validation loss is 0.39260814

# %%
model_path= "./misc/aec_lstm_160_may23.pth"
torch.save(model.state_dict(),model_path)

# %%
model_path= "./misc/aec_lstm_160_may23.pth"
model=LSTMNet(input_dim=specdims[0]*2, hidden_dim=25, fclayer_dim=25, output_dim=specdims[0], num_layers=1,dropout_prob=0.0)
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
dataset=ICASSPDatasetHelper()
#test_index=19485
#test_index=1970
test_index=27790
model.to(device="cpu")
mic,_= dataset.get_indxd_file(test_index,2)
fend,_= dataset.get_indxd_file(test_index,3)
nend,_= dataset.get_indxd_file(test_index,4)
echo,_= dataset.get_indxd_file(test_index,1)
mic = torch.tensor(mic)
fend = torch.tensor(fend)
nend = torch.tensor(nend)
y=torch.permute(mic,(1,0))
x=torch.concat((mic,fend),0)
x= torch.permute(x,(1,0))
x=x.unsqueeze(0)
x=x.to(dtype=torch.float32)
model.eval()
with torch.no_grad():
    out=model(x*x)
out = out *y
out=out.squeeze(0)
out= torch.permute(out,(1,0))

# %%
plt.figure()
plt.title("Comparison of echo cancellation output vs Ground Truth")
ax1=plt.subplot(1,4,1)
ax1.imshow(np.flip(mic.numpy(),0))
ax1.title.set_text("mic input")
ax2=plt.subplot(1,4,2)
ax2.imshow(np.flip(out.cpu().numpy()))
ax2.title.set_text("output")
ax3=plt.subplot(1,4,3)
ax3.imshow(np.flip(nend.numpy()))
ax3.title.set_text("GT near end")
ax4=plt.subplot(1,4,4)
ax4.imshow(np.flip(echo))
ax4.title.set_text("echo")

# %%
plt.plot(train_loss)
plt.plot(val_loss)
plt.legend(["train loss","validation loss"])

# %% [markdown]
# Run a test file using the model to process and remove the echo

# %%
file_indx=97
mic_sig,_=librosa.load("../dataset/AEC-Challenge/datasets/synthetic/nearend_mic_signal/nearend_mic_fileid_"+str(file_indx)+".wav",sr=8000)
fend_sig,_=librosa.load("../dataset/AEC-Challenge/datasets/synthetic/farend_speech/farend_speech_fileid_"+str(file_indx)+".wav",sr=8000)
nend_sig,_=librosa.load("../dataset/AEC-Challenge/datasets/synthetic/nearend_speech/nearend_speech_fileid_"+str(file_indx)+".wav",sr=8000)

# %%
nfft_len=318
mic_stft=librosa.stft(mic_sig,n_fft=nfft_len, hop_length=nfft_len//4,center=True)
fend_stft=librosa.stft(fend_sig,n_fft=nfft_len, hop_length=nfft_len//4,center=True)
nend_stft=librosa.stft(nend_sig,n_fft=nfft_len, hop_length=nfft_len//4,center=True)

# %%
fx=librosa.stft(fend_sig,n_fft=318,hop_length=318//4)
res_spec=np.zeros_like(fx)
for i in range(0,31):
    mic=  mic_stft[:,specdims[1]*i:specdims[1]*i+specdims[1]]
    fend= fend_stft[:,specdims[1]*i:specdims[1]*i+specdims[1]]
    nend= nend_stft[:,specdims[1]*i:specdims[1]*i+specdims[1]]
    tmic = torch.tensor(abs(mic))
    tfend = torch.tensor(abs(fend))
    tnend = torch.tensor(abs(nend))
    y=torch.permute(tmic,(1,0))
    x=torch.concat((tmic,tfend),0)
    x= torch.permute(x,(1,0))
    x=x.unsqueeze(0)
    x=x.to(dtype=torch.float32)
    model.eval()
    with torch.no_grad():
        out=model(x*x)
    out = out*y
    out=out.squeeze(0)
    out= torch.permute(out,(1,0))
    out=out.cpu().numpy()
    mag,ph=librosa.magphase(mic)
    out=out*ph
    #print(out.shape)
    res_spec[:,specdims[1]*i:specdims[1]*i+specdims[1]]=out
    #specs[:,specdims[1]*i:specdims[1]*i+specdims[1]]=out*spec
res_nend=librosa.istft(res_spec,hop_length=nfft_len//4,n_fft=nfft_len)
#res_nend=librosa.util.normalize(res_nend)
print(res_nend.shape)
# Out:
# (79948,)

# %%
plt.figure()
plt.plot(mic_sig)
plt.plot(res_nend)
plt.figure()
plt.plot(nend_sig)

# %% [markdown]
# Dump processed files

# %%
wav.write("../op/echo_cancelled_fileid_"+str(file_indx)+".wav", 8000, res_nend)
wav.write("../op/mic_fileid_"+str(file_indx)+".wav", 8000, mic_sig)
wav.write("../op/nend_fileid_"+str(file_indx)+".wav", 8000, nend_sig)
wav.write("../op/fend_fileid_"+str(file_indx)+".wav", 8000, fend_sig)

# %%
class NLMS():
    #initialize
    def __init__(self,mu,taps):
        self.mu=mu
        self.N=taps
        self.e=0
        self.w=np.zeros((taps,1))
        self.xd=np.zeros((taps,1))

    #updates the filter sample by sample and updates weights sample by sample
    def run(self,x,d):
        N=self.N
        #udpate delay line 
        self.xd[0]=x
        #compute filter output
        y = np.dot(self.w.T,self.xd)
        #compute input energy
        pw=np.linalg.norm(self.xd)
        pw=pw*pw
        #pw=pw*pw
        #calculate error
        e = d - y
        self.e=e

        #normalize by input energy
        e= e/(pw+0.0000000001)
        #compute gradients
        Fw=self.mu*np.multiply(self.xd,e)
        
        Fw=Fw.reshape(Fw.shape[0],-1)
        #weight update
        self.w = self.w + Fw
    
        #filtered output post update
        y = np.dot(self.w.T,self.xd)
        #shift delay line
        self.xd[1:]=self.xd[:-1]
 
        #return current output sample, current error sample and current weights
        return (y,self.e,self.w)

# %%
#test wrapper for NLMS filter on aec data for single talk case
taps=1024
lmscls= NLMS(0.0001,taps)
w1=np.zeros((taps,1))
y1=np.zeros_like(fend_sig)
e1=np.zeros_like(fend_sig)
for i in range(0,len(res_nend)):
    (y1[i],e1[i],w3)=lmscls.run(fend_sig[i],res_nend[i])

# %%
plt.figure()
plt.plot(mic_sig)
plt.plot(e1)
plt.figure()
plt.plot(nend_sig)

# %%
wav.write("../op/lmsnecho_cancelled_fileid_"+str(file_indx)+".wav", 8000, e1)
wav.write("../op/mic_fileid_"+str(file_indx)+".wav", 8000, mic_sig)
wav.write("../op/nend_fileid_"+str(file_indx)+".wav", 8000, nend_sig)
wav.write("../op/fend_fileid_"+str(file_indx)+".wav", 8000, fend_sig)
