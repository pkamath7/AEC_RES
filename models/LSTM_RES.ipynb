# %%
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import os
import numpy as np
import torch.nn as nn
import pandas as pd
import librosa
import librosa.display
from torch.utils.data import sampler
import torch.optim as optim
import json
import cv2
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
from torchinfo import summary
from IPython.display import Audio
import IPython.display as ipd
import soundfile as sd
import padasip as dsp

# %%
class DAPSDatasetHelper():
    #initialization 
    def __init__(self):
        self.sample_rate=8000
        fft_len=40
        hop_len=10
        self.dir= "./daps_dict_unet2.json"
        openfile=open(self.dir, "r")
        self.dataset_dict= json.load(openfile)
        indx=2
        self.keys={}
        for key  in self.dataset_dict.keys():
            if(key=="produced"):
                self.keys[1]=key
            else:
                self.keys[indx]=key
                indx+=1

        self.num_files_per_category=len(self.dataset_dict["produced"].keys())

    #get the indexed file and sample rate
    def get_indxd_file(self,indx,isLabel=False):
        if(isLabel):
            category=self.keys[1]
        else:
            #category=self.keys[np.random.randint(2,len(self.keys))]
            #consider one category for now
            category=self.keys[4]
        data=cv2.imread(self.dataset_dict[category][str(indx)],0)
        data= cv2.normalize(data, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        Id= self.dataset_dict[category][str(indx)].split("/")[-1].split('.')[0]
        return (data,Id)

# %%
class FeatureExtractor():
    def __init__(self,fft_len,hop_size,sr):
        self.fft_len=int(fft_len*sr//1000)
        self.hop_size=int(hop_size*sr//1000)
        self.sr= sr
        self.spec_dims=(160,32)
        self.fft_buff=np.zeros((self.fft_len,1))
        self.ifft_buff=np.zeros((self.fft_len,1))
        self.wnd=np.hanning(self.fft_len)
        self.zbuf=np.zeros((self.hop_size,1))
        self.specgram=np.zeros((self.spec_dims[0],self.spec_dims[1]))

    def stft(self,x):
        R=self.hop_size
        M= self.fft_len
        x=x.reshape((x.shape[0],-1))
        self.fft_buff[M-R:,:]=x
        xw=np.multiply(self.fft_buff.T,self.wnd)
        fft_xw=np.fft.fft(xw,n=M).T
        self.fft_buff[:M-R,:]=self.fft_buff[R:,:]
        return fft_xw

    def istft(self,x):
        R=self.hop_size
        M= self.fft_len
        iift_xw= np.fft.ifft(x.T,self.fft_len)
        y=self.ifft_buff[:R]
        self.ifft_buff[:M-R]=self.ifft_buff[R:]
        self.ifft_buff[M-R:]=self.zbuf
        self.ifft_buff=self.ifft_buff+iift_xw.T
        return y.real
    
    def spectrogram(self,fft_x):
        self.specgram[:,:-1]=self.specgram[:,1:]
        self.specgram[:,-1]=np.abs(fft_x)[:self.spec_dims[0],0]
        y=cv2.normalize(self.specgram, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        #y=np.flip(y,0)
        return y

# %%
class DAPS(Dataset):
    def __init__(self):
        #super().__init__(self)
        self.daps= DAPSDatasetHelper()

    def __getitem__(self, index):
        data,id=self.daps.get_indxd_file(index)
        label,id=self.daps.get_indxd_file(index,True)
        return (data,label)

    def __len__(self):
        return (len(self.daps.keys)-1)*self.daps.num_files_per_category

# %%
dtype = torch.float32 # we will be using float throughout this tutorial
USE_GPU = True
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print(device)
# Out:
# cuda

# %%
def flatten(x):
    N = x.shape[0] # read in N, C, H, W
    return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %%
NUM_TRAIN=16000
NUM_VAL=2000
NUM_TEST=2000
print_every = 100
dataset_train = DAPS()
batch_size=16
loader_train = DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_TRAIN)))
loader_val= DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_TRAIN,NUM_VAL+NUM_TRAIN)))
loader_test = DataLoader(dataset_train, batch_size=batch_size, num_workers=8,
                          sampler=sampler.SequentialSampler(range(NUM_VAL+NUM_TRAIN, NUM_VAL+NUM_TRAIN+NUM_TEST)))

helper= DAPSDatasetHelper()

# %%
print(dataset_train.daps.keys)
# Out:
# {2: 'iphone_bedroom1', 3: 'iphone_balcony1', 4: 'ipad_confroom1', 5: 'clean', 6: 'iphone_livingroom1', 7: 'ipad_confroom2', 8: 'ipad_livingroom1', 9: 'cleanraw', 1: 'produced', 10: 'ipadflat_office1', 11: 'ipadflat_confroom1', 12: 'ipad_office1', 13: 'ipad_balcony1', 14: 'ipad_bedroom1', 15: 'sample', 16: 'ipad_office2'}

# %%
#Create Model classes
# create a class for linear layers 
class DenseLayer(nn.Module):
    def __init__(self,input_size,output_size,dropOut_p):
        super().__init__()
        self.dense=nn.Linear(input_size,output_size,bias=True)
        self.activation=nn.Tanh()
        self.dropOut=nn.Dropout(p=dropOut_p,inplace=False)
    
    def forward(self,x):
        y=self.dense(x)
        y=self.activation(y)
        y=self.dropOut(y)
        return y

#class for convolutional layers
class ConvLayer(nn.Module):
    def __init__(self,in_ch,out_ch,kernel_size,stride,padding,dropOut_p):
        super().__init__()
        self.conv=nn.Conv2d(in_ch,out_ch,kernel_size, stride=stride,padding=padding)
        self.activation=nn.ReLU()
        self.dropOut=nn.Dropout2d(p=dropOut_p,inplace=False)
    
    def forward(self,x):
        y=self.conv(x)
        y=self.activation(y)
        y=self.dropOut(y)

        return y

#RNN model for Residual echo suppression
class LSTMNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, fclayer_dim, output_dim, num_layers,dropout_prob):
        super().__init__()
        # Defining the number of layers and the nodes in each layer
        self.layer_dim=num_layers
        self.hidden_dim=hidden_dim
        self.rnn = nn.LSTM(
            fclayer_dim, hidden_dim, num_layers, batch_first=True
        )
        self.tanh=nn.Tanh()
        self.fc1= nn.Linear(input_dim,fclayer_dim)
        self.fc2= nn.Linear(hidden_dim,output_dim)
        self.sig=nn.Sigmoid()
        self.relu= nn.ReLU()


    def forward(self, x):
        
        y= self.fc1(x)

        y= self.relu(y)
        # Initializing hidden state for first input with zeros
        h0 = torch.zeros(self.layer_dim, y.size(0), self.hidden_dim).requires_grad_()

        # Forward propagation by passing in the input and hidden state into the model
        out, h0 = self.rnn(y)

        # Reshaping the outputs in the shape of (batch_size, seq_length, hidden_size)
        # so that it can fit into the fully connected layer
        #out = out[:, -1, :]
        out=self.relu(out)
        # Convert the final state to our desired output shape (batch_size, output_dim)
        out = self.fc2(out)
        out = self.sig(out)
        return out

# %%
#SNR loss where yhat is average power spectrum of de-nonlinearised/denoised signal/ clean signal power 
def Loss_MSE(yhat,y,lossfn):
    target = torch.ones(1).to(device=device)
    #yhat=yhat.squeeze(0)
    #y=y.squeeze(0)
    #loss=lossfn(yhat,y,target)
    loss=lossfn(yhat,y)
    return loss

# %%
def check_accuracy(loader, model,lossfn):
    print('Checking accuracy on validation set')
    model.eval()  # set model to evaluation mode
    mse=0
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=dtype)

            x=torch.permute(x, (0, 2, 1))
            y=torch.permute(y, (0, 2, 1))
            pw_x=x*x

            # Forward pass: compute scores and loss
            mask = model(pw_x)

            yhat= mask*x
            #yhat=yhat[:,:,:,-1]
            #y=y[:,:,:,-1]
            mse+= Loss_MSE(y,yhat,lossfn)
        mse = mse / len(loader)
        print("Validation loss is", mse.cpu().numpy())
        return  mse.cpu().numpy()

# %%
print_every=1
def train_model(model, optimizer, scheduler ,epochs=1):
    """
    Train a model on DAPS.
    
    Inputs:
    - model_fn: A Python function that performs the forward pass of the model.
      It should have the signature scores = model_fn(x, params) where x is a
      PyTorch Tensor of image data, params is a list of PyTorch Tensors giving
      model weights, and scores is a PyTorch Tensor of shape (N, C) giving
      scores for the elements in x.
    - params: List of PyTorch Tensors giving weights for the model
    - learning_rate: Python scalar giving the learning rate to use for SGD
    
    Returns: val loss and train loss
    """
    val_loss=[]
    train_loss=[]
    #lossfn=nn.CosineEmbeddingLoss(margin=0,reduction="mean")
    lossfn=nn.MSELoss()
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        running_loss = 0
        for t, (x, y) in enumerate(loader_train):
            
            #print(y.shape)          
            #iterate over each stft frame 
            x=x.to(device=device, dtype=dtype)
            y=y.to(device=device, dtype=dtype)
            
            x=torch.permute(x, (0, 2, 1))
            y=torch.permute(y, (0, 2, 1))
            
            pw_x=x*x

            # Forward pass: compute scores and loss
            mask = model(pw_x)

            #print(mask.shape)

            yhat= mask*x

            #yhat=yhat[:,:,:,-1]
            #y=y[:,:,:,-1]

            loss = Loss_MSE(yhat, y, lossfn)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            # Update parameters. We don't want to backpropagate through the
            running_loss += loss.item()
            

        if t % print_every == 0:
            print('Epoch %d, Iteration %d, loss = %.8f' % (e, t, (running_loss/len(loader_train))))
            train_loss.append(running_loss/len(loader_train))
            #check_accuracy_part2(loader_val, model_fn, params)
            
        vloss=check_accuracy(loader_val,model,lossfn)
        model.train()
        val_loss.append(vloss)
        scheduler.step(loss)
    return (train_loss,val_loss)

# %%
learning_rate = 1e-3

model = LSTMNet(input_dim=160, hidden_dim=25, fclayer_dim=25, output_dim=160, num_layers=1,dropout_prob=0.2)
# you can use Nesterov momentum in optim.SGD
#optimizer = optim.SGD(model.parameters(), lr=learning_rate,
#                     momentum=0.9, nesterov=True)
# you can use Nesterov momentum in optim.SGD
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

# %%
batch_size = batch_size
summary(model, input_size=(batch_size,32, 160))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LSTMNet                                  --                        --
# ├─LSTM: 1-1                              --                        (recursive)
# ├─Tanh: 1-2                              --                        --
# ├─Linear: 1-3                            [16, 32, 25]              4,025
# ├─ReLU: 1-4                              [16, 32, 25]              --
# ├─LSTM: 1-5                              [16, 32, 25]              5,200
# ├─ReLU: 1-6                              --                        --
# ├─ReLU: 1-7                              [16, 32, 25]              --
# ├─Linear: 1-8                            [16, 32, 160]             4,160
# ├─Sigmoid: 1-9                           [16, 32, 160]             --
# ==========================================================================================
# Total params: 13,385
# Trainable params: 13,385
# Non-trainable params: 0
# Total mult-adds (M): 2.79
# ==========================================================================================
# Input size (MB): 0.33
# Forward/backward pass size (MB): 0.86
# Params size (MB): 0.05
# Estimated Total Size (MB): 1.24
# ==========================================================================================

# %%
(train_loss,val_loss)=train_model(model, optimizer, scheduler,500)
# Out:
# Epoch 0, Iteration 999, loss = 0.03374257
# Checking accuracy on validation set
# Validation loss is 0.027752906
# Epoch 1, Iteration 999, loss = 0.03273836
# Checking accuracy on validation set
# Validation loss is 0.027695097
# Epoch 2, Iteration 999, loss = 0.03265721
# Checking accuracy on validation set
# Validation loss is 0.027658757
# Epoch 3, Iteration 999, loss = 0.03262356
# Checking accuracy on validation set
# Validation loss is 0.027608633
# Epoch 4, Iteration 999, loss = 0.03259121
# Checking accuracy on validation set
# Validation loss is 0.027565738
# Epoch 5, Iteration 999, loss = 0.03255283
# Checking accuracy on validation set
# Validation loss is 0.027547644
# Epoch 6, Iteration 999, loss = 0.03250913
# Checking accuracy on validation set
# Validation loss is 0.027527347
# Epoch 7, Iteration 999, loss = 0.03247306
# Checking accuracy on validation set
# Validation loss is 0.027503595
# Epoch 8, Iteration 999, loss = 0.03243753
# Checking accuracy on validation set
# Validation loss is 0.02746143
# Epoch 9, Iteration 999, loss = 0.03238398
# Checking accuracy on validation set
# Validation loss is 0.02741585
# Epoch 10, Iteration 999, loss = 0.03232849
# Checking accuracy on validation set
# Validation loss is 0.027372299
# Epoch 11, Iteration 999, loss = 0.03228673
# Checking accuracy on validation set
# Validation loss is 0.027337605
# Epoch 12, Iteration 999, loss = 0.03225674
# Checking accuracy on validation set
# Validation loss is 0.027313069
# Epoch 13, Iteration 999, loss = 0.03223287
# Checking accuracy on validation set
# Validation loss is 0.027291078
# Epoch 14, Iteration 999, loss = 0.03221131
# Checking accuracy on validation set
# Validation loss is 0.027270686
# Epoch 15, Iteration 999, loss = 0.03219119
# Checking accuracy on validation set
# Validation loss is 0.027250897
# Epoch 16, Iteration 999, loss = 0.03216997
# Checking accuracy on validation set
# Validation loss is 0.027228307
# Epoch 17, Iteration 999, loss = 0.03214880
# Checking accuracy on validation set
# Validation loss is 0.027203709
# Epoch 18, Iteration 999, loss = 0.03211225
# Checking accuracy on validation set
# Validation loss is 0.027171168
# Epoch 19, Iteration 999, loss = 0.03208691
# Checking accuracy on validation set
# Validation loss is 0.027141863
# Epoch 20, Iteration 999, loss = 0.03206558
# Checking accuracy on validation set
# Validation loss is 0.027123982
# Epoch 21, Iteration 999, loss = 0.03204926
# Checking accuracy on validation set
# Validation loss is 0.027110582
# Epoch 22, Iteration 999, loss = 0.03203498
# Checking accuracy on validation set
# Validation loss is 0.027095197
# Epoch 23, Iteration 999, loss = 0.03202109
# Checking accuracy on validation set
# Validation loss is 0.027084716
# Epoch 24, Iteration 999, loss = 0.03200725
# Checking accuracy on validation set
# Validation loss is 0.027071975
# Epoch 25, Iteration 999, loss = 0.03199417
# Checking accuracy on validation set
# Validation loss is 0.027058948
# Epoch 26, Iteration 999, loss = 0.03198228
# Checking accuracy on validation set
# Validation loss is 0.027042948
# Epoch 27, Iteration 999, loss = 0.03197021
# Checking accuracy on validation set
# Validation loss is 0.027029678
# Epoch 28, Iteration 999, loss = 0.03195511
# Checking accuracy on validation set
# Validation loss is 0.02701716
# Epoch 29, Iteration 999, loss = 0.03193507
# Checking accuracy on validation set
# Validation loss is 0.027000664
# Epoch 30, Iteration 999, loss = 0.03191053
# Checking accuracy on validation set
# Validation loss is 0.026982822
# Epoch 31, Iteration 999, loss = 0.03188644
# Checking accuracy on validation set
# Validation loss is 0.02696392
# Epoch 32, Iteration 999, loss = 0.03186201
# Checking accuracy on validation set
# Validation loss is 0.0269416
# Epoch 33, Iteration 999, loss = 0.03183851
# Checking accuracy on validation set
# Validation loss is 0.026924945
# Epoch 34, Iteration 999, loss = 0.03181749
# Checking accuracy on validation set
# Validation loss is 0.02690837
# Epoch 35, Iteration 999, loss = 0.03179486
# Checking accuracy on validation set
# Validation loss is 0.026886964
# Epoch 36, Iteration 999, loss = 0.03177172
# Checking accuracy on validation set
# Validation loss is 0.026866123
# Epoch 37, Iteration 999, loss = 0.03175083
# Checking accuracy on validation set
# Validation loss is 0.02684279
# Epoch 38, Iteration 999, loss = 0.03173451
# Checking accuracy on validation set
# Validation loss is 0.026825907
# Epoch 39, Iteration 999, loss = 0.03171888
# Checking accuracy on validation set
# Validation loss is 0.026809845
# Epoch 40, Iteration 999, loss = 0.03170307
# Checking accuracy on validation set
# Validation loss is 0.026793227
# Epoch 41, Iteration 999, loss = 0.03168693
# Checking accuracy on validation set
# Validation loss is 0.026780806
# Epoch 42, Iteration 999, loss = 0.03167126
# Checking accuracy on validation set
# Validation loss is 0.026765043
# Epoch 43, Iteration 999, loss = 0.03165847
# Checking accuracy on validation set
# Validation loss is 0.02675422
# Epoch 44, Iteration 999, loss = 0.03164705
# Checking accuracy on validation set
# Validation loss is 0.026742142
# Epoch 45, Iteration 999, loss = 0.03163666
# Checking accuracy on validation set
# Validation loss is 0.026730558
# Epoch 46, Iteration 999, loss = 0.03162734
# Checking accuracy on validation set
# Validation loss is 0.026719047
# Epoch 47, Iteration 999, loss = 0.03161855
# Checking accuracy on validation set
# Validation loss is 0.026710512
# Epoch 48, Iteration 999, loss = 0.03161267
# Checking accuracy on validation set
# Validation loss is 0.026700148
# Epoch 49, Iteration 999, loss = 0.03160144
# Checking accuracy on validation set
# Validation loss is 0.026694907
# Epoch 50, Iteration 999, loss = 0.03159193
# Checking accuracy on validation set
# Validation loss is 0.026687063
# Epoch 51, Iteration 999, loss = 0.03158217
# Checking accuracy on validation set
# Validation loss is 0.026680924
# Epoch 52, Iteration 999, loss = 0.03157268
# Checking accuracy on validation set
# Validation loss is 0.026671166
# Epoch 53, Iteration 999, loss = 0.03156363
# Checking accuracy on validation set
# Validation loss is 0.0266639
# Epoch 54, Iteration 999, loss = 0.03156365
# Checking accuracy on validation set
# Validation loss is 0.02665144
# Epoch 55, Iteration 999, loss = 0.03154892
# Checking accuracy on validation set
# Validation loss is 0.026644493
# Epoch 56, Iteration 999, loss = 0.03153961
# Checking accuracy on validation set
# Validation loss is 0.026639856
# Epoch 57, Iteration 999, loss = 0.03153264
# Checking accuracy on validation set
# Validation loss is 0.026634574
# Epoch 58, Iteration 999, loss = 0.03152658
# Checking accuracy on validation set
# Validation loss is 0.026627345
# Epoch 59, Iteration 999, loss = 0.03152032
# Checking accuracy on validation set
# Validation loss is 0.026621608
# Epoch 60, Iteration 999, loss = 0.03151519
# Checking accuracy on validation set
# Validation loss is 0.02661771
# Epoch 61, Iteration 999, loss = 0.03150952
# Checking accuracy on validation set
# Validation loss is 0.026611326
# Epoch 62, Iteration 999, loss = 0.03150486
# Checking accuracy on validation set
# Validation loss is 0.026605612
# Epoch 63, Iteration 999, loss = 0.03149905
# Checking accuracy on validation set
# Validation loss is 0.02660399
# Epoch 64, Iteration 999, loss = 0.03149463
# Checking accuracy on validation set
# Validation loss is 0.026598163
# Epoch 65, Iteration 999, loss = 0.03148972
# Checking accuracy on validation set
# Validation loss is 0.02659411
# Epoch 66, Iteration 999, loss = 0.03148566
# Checking accuracy on validation set
# Validation loss is 0.02658855
# Epoch 67, Iteration 999, loss = 0.03148001
# Checking accuracy on validation set
# Validation loss is 0.026584303
# Epoch 68, Iteration 999, loss = 0.03147615
# Checking accuracy on validation set
# Validation loss is 0.026580207
# Epoch 69, Iteration 999, loss = 0.03147143
# Checking accuracy on validation set
# Validation loss is 0.026576163
# Epoch 70, Iteration 999, loss = 0.03146730
# Checking accuracy on validation set
# Validation loss is 0.026577326
# Epoch 71, Iteration 999, loss = 0.03146252
# Checking accuracy on validation set
# Validation loss is 0.026575636
# Epoch 72, Iteration 999, loss = 0.03145783
# Checking accuracy on validation set
# Validation loss is 0.026574453
# Epoch 73, Iteration 999, loss = 0.03145274
# Checking accuracy on validation set
# Validation loss is 0.0265709
# Epoch 74, Iteration 999, loss = 0.03144910
# Checking accuracy on validation set
# Validation loss is 0.026567569
# Epoch 75, Iteration 999, loss = 0.03144457
# Checking accuracy on validation set
# Validation loss is 0.026558442
# Epoch 76, Iteration 999, loss = 0.03143899
# Checking accuracy on validation set
# Validation loss is 0.026555369
# Epoch 77, Iteration 999, loss = 0.03143514
# Checking accuracy on validation set
# Validation loss is 0.026549933
# Epoch 78, Iteration 999, loss = 0.03143146
# Checking accuracy on validation set
# Validation loss is 0.026544096
# Epoch 79, Iteration 999, loss = 0.03142579
# Checking accuracy on validation set
# Validation loss is 0.026542345
# Epoch 80, Iteration 999, loss = 0.03142108
# Checking accuracy on validation set
# Validation loss is 0.026535219
# Epoch 81, Iteration 999, loss = 0.03141783
# Checking accuracy on validation set
# Validation loss is 0.026529929
# Epoch 82, Iteration 999, loss = 0.03141239
# Checking accuracy on validation set
# Validation loss is 0.026524367
# Epoch 83, Iteration 999, loss = 0.03140617
# Checking accuracy on validation set
# Validation loss is 0.026517339
# Epoch 84, Iteration 999, loss = 0.03140092
# Checking accuracy on validation set
# Validation loss is 0.026513904
# Epoch 85, Iteration 999, loss = 0.03139681
# Checking accuracy on validation set
# Validation loss is 0.02650983
# Epoch 86, Iteration 999, loss = 0.03139408
# Checking accuracy on validation set
# Validation loss is 0.026503464
# Epoch 87, Iteration 999, loss = 0.03138825
# Checking accuracy on validation set
# Validation loss is 0.026501428
# Epoch 88, Iteration 999, loss = 0.03138333
# Checking accuracy on validation set
# Validation loss is 0.0264977
# Epoch 89, Iteration 999, loss = 0.03138043
# Checking accuracy on validation set
# Validation loss is 0.02649307
# Epoch 90, Iteration 999, loss = 0.03137603
# Checking accuracy on validation set
# Validation loss is 0.026489547
# Epoch 91, Iteration 999, loss = 0.03137309
# Checking accuracy on validation set
# Validation loss is 0.026484057
# Epoch 92, Iteration 999, loss = 0.03136878
# Checking accuracy on validation set
# Validation loss is 0.026480615
# Epoch 93, Iteration 999, loss = 0.03136717
# Checking accuracy on validation set
# Validation loss is 0.026478933
# Epoch 94, Iteration 999, loss = 0.03136203
# Checking accuracy on validation set
# Validation loss is 0.026475355
# Epoch 95, Iteration 999, loss = 0.03135924
# Checking accuracy on validation set
# Validation loss is 0.026469635
# Epoch 96, Iteration 999, loss = 0.03135427
# Checking accuracy on validation set
# Validation loss is 0.026465788
# Epoch 97, Iteration 999, loss = 0.03135073
# Checking accuracy on validation set
# Validation loss is 0.026463151
# Epoch 98, Iteration 999, loss = 0.03134555
# Checking accuracy on validation set
# Validation loss is 0.026457911
# Epoch 99, Iteration 999, loss = 0.03133940
# Checking accuracy on validation set
# Validation loss is 0.026454732
# Epoch 100, Iteration 999, loss = 0.03133378
# Checking accuracy on validation set
# Validation loss is 0.02644687
# Epoch 101, Iteration 999, loss = 0.03132610
# Checking accuracy on validation set
# Validation loss is 0.02644036
# Epoch 102, Iteration 999, loss = 0.03131912
# Checking accuracy on validation set
# Validation loss is 0.026434377
# Epoch 103, Iteration 999, loss = 0.03131377
# Checking accuracy on validation set
# Validation loss is 0.026430571
# Epoch 104, Iteration 999, loss = 0.03130920
# Checking accuracy on validation set
# Validation loss is 0.026428092
# Epoch 105, Iteration 999, loss = 0.03130815
# Checking accuracy on validation set
# Validation loss is 0.026423384
# Epoch 106, Iteration 999, loss = 0.03130284
# Checking accuracy on validation set
# Validation loss is 0.026418958
# Epoch 107, Iteration 999, loss = 0.03129875
# Checking accuracy on validation set
# Validation loss is 0.026416736
# Epoch 108, Iteration 999, loss = 0.03129675
# Checking accuracy on validation set
# Validation loss is 0.026413338
# Epoch 109, Iteration 999, loss = 0.03129583
# Checking accuracy on validation set
# Validation loss is 0.026409214
# Epoch 110, Iteration 999, loss = 0.03130278
# Checking accuracy on validation set
# Validation loss is 0.026398392
# Epoch 111, Iteration 999, loss = 0.03129024
# Checking accuracy on validation set
# Validation loss is 0.026400058
# Epoch 112, Iteration 999, loss = 0.03128566
# Checking accuracy on validation set
# Validation loss is 0.02639956
# Epoch 113, Iteration 999, loss = 0.03128199
# Checking accuracy on validation set
# Validation loss is 0.026398716
# Epoch 114, Iteration 999, loss = 0.03127990
# Checking accuracy on validation set
# Validation loss is 0.026398027
# Epoch 115, Iteration 999, loss = 0.03127615
# Checking accuracy on validation set
# Validation loss is 0.026394578
# Epoch 116, Iteration 999, loss = 0.03127817
# Checking accuracy on validation set
# Validation loss is 0.02639441
# Epoch 117, Iteration 999, loss = 0.03127294
# Checking accuracy on validation set
# Validation loss is 0.026391774
# Epoch 118, Iteration 999, loss = 0.03127013
# Checking accuracy on validation set
# Validation loss is 0.026388334
# Epoch 119, Iteration 999, loss = 0.03126713
# Checking accuracy on validation set
# Validation loss is 0.02638586
# Epoch 120, Iteration 999, loss = 0.03126632
# Checking accuracy on validation set
# Validation loss is 0.02638397
# Epoch 121, Iteration 999, loss = 0.03126341
# Checking accuracy on validation set
# Validation loss is 0.026383381
# Epoch 122, Iteration 999, loss = 0.03126061
# Checking accuracy on validation set
# Validation loss is 0.026379604
# Epoch 123, Iteration 999, loss = 0.03126005
# Checking accuracy on validation set
# Validation loss is 0.026376225
# Epoch 124, Iteration 999, loss = 0.03125751
# Checking accuracy on validation set
# Validation loss is 0.026372954
# Epoch 125, Iteration 999, loss = 0.03125478
# Checking accuracy on validation set
# Validation loss is 0.026371572
# Epoch 126, Iteration 999, loss = 0.03125327
# Checking accuracy on validation set
# Validation loss is 0.026369343
# Epoch 127, Iteration 999, loss = 0.03125157
# Checking accuracy on validation set
# Validation loss is 0.026369035
# Epoch 128, Iteration 999, loss = 0.03124807
# Checking accuracy on validation set
# Validation loss is 0.026367046
# Epoch 129, Iteration 999, loss = 0.03124579
# Checking accuracy on validation set
# Validation loss is 0.026363585
# Epoch 130, Iteration 999, loss = 0.03124413
# Checking accuracy on validation set
# Validation loss is 0.026361113
# Epoch 131, Iteration 999, loss = 0.03124365
# Checking accuracy on validation set
# Validation loss is 0.02635918
# Epoch 132, Iteration 999, loss = 0.03124199
# Checking accuracy on validation set
# Validation loss is 0.026357276
# Epoch 133, Iteration 999, loss = 0.03123977
# Checking accuracy on validation set
# Validation loss is 0.026355384
# Epoch 134, Iteration 999, loss = 0.03123747
# Checking accuracy on validation set
# Validation loss is 0.02635302
# Epoch 135, Iteration 999, loss = 0.03123607
# Checking accuracy on validation set
# Validation loss is 0.026352022
# Epoch 136, Iteration 999, loss = 0.03123678
# Checking accuracy on validation set
# Validation loss is 0.026349941
# Epoch 137, Iteration 999, loss = 0.03123364
# Checking accuracy on validation set
# Validation loss is 0.026349524
# Epoch 138, Iteration 999, loss = 0.03123129
# Checking accuracy on validation set
# Validation loss is 0.026346877
# Epoch 139, Iteration 999, loss = 0.03122893
# Checking accuracy on validation set
# Validation loss is 0.026346399
# Epoch 140, Iteration 999, loss = 0.03122755
# Checking accuracy on validation set
# Validation loss is 0.026345342
# Epoch 141, Iteration 999, loss = 0.03122795
# Checking accuracy on validation set
# Validation loss is 0.026343143
# Epoch 142, Iteration 999, loss = 0.03122612
# Checking accuracy on validation set
# Validation loss is 0.026340596
# Epoch 143, Iteration 999, loss = 0.03122335
# Checking accuracy on validation set
# Validation loss is 0.026340568
# Epoch 144, Iteration 999, loss = 0.03122148
# Checking accuracy on validation set
# Validation loss is 0.026338682
# Epoch 145, Iteration 999, loss = 0.03122279
# Checking accuracy on validation set
# Validation loss is 0.026336567
# Epoch 146, Iteration 999, loss = 0.03122628
# Checking accuracy on validation set
# Validation loss is 0.026402216
# Epoch 147, Iteration 999, loss = 0.03123182
# Checking accuracy on validation set
# Validation loss is 0.026333129
# Epoch 148, Iteration 999, loss = 0.03121956
# Checking accuracy on validation set
# Validation loss is 0.026331874
# Epoch 149, Iteration 999, loss = 0.03121647
# Checking accuracy on validation set
# Validation loss is 0.026332976
# Epoch 150, Iteration 999, loss = 0.03121368
# Checking accuracy on validation set
# Validation loss is 0.026332298
# Epoch 151, Iteration 999, loss = 0.03121257
# Checking accuracy on validation set
# Validation loss is 0.026331205
# Epoch 152, Iteration 999, loss = 0.03121203
# Checking accuracy on validation set
# Validation loss is 0.026329037
# Epoch 153, Iteration 999, loss = 0.03120925
# Checking accuracy on validation set
# Validation loss is 0.026328845
# Epoch 154, Iteration 999, loss = 0.03121176
# Checking accuracy on validation set
# Validation loss is 0.026325366
# Epoch 155, Iteration 999, loss = 0.03120780
# Checking accuracy on validation set
# Validation loss is 0.026325764
# Epoch 156, Iteration 999, loss = 0.03120639
# Checking accuracy on validation set
# Validation loss is 0.02632679
# Epoch 157, Iteration 999, loss = 0.03120414
# Checking accuracy on validation set
# Validation loss is 0.026325062
# Epoch 158, Iteration 999, loss = 0.03120249
# Checking accuracy on validation set
# Validation loss is 0.02632316
# Epoch 159, Iteration 999, loss = 0.03120392
# Checking accuracy on validation set
# Validation loss is 0.026320813
# Epoch 160, Iteration 999, loss = 0.03120111
# Checking accuracy on validation set
# Validation loss is 0.026320072
# Epoch 161, Iteration 999, loss = 0.03120423
# Checking accuracy on validation set
# Validation loss is 0.026319128
# Epoch 162, Iteration 999, loss = 0.03119963
# Checking accuracy on validation set
# Validation loss is 0.026316766
# Epoch 163, Iteration 999, loss = 0.03119852
# Checking accuracy on validation set
# Validation loss is 0.026316408
# Epoch 164, Iteration 999, loss = 0.03119600
# Checking accuracy on validation set
# Validation loss is 0.026314259
# Epoch 165, Iteration 999, loss = 0.03119324
# Checking accuracy on validation set
# Validation loss is 0.026313122
# Epoch 166, Iteration 999, loss = 0.03119205
# Checking accuracy on validation set
# Validation loss is 0.02631198
# Epoch 167, Iteration 999, loss = 0.03119082
# Checking accuracy on validation set
# Validation loss is 0.026310517
# Epoch 168, Iteration 999, loss = 0.03119003
# Checking accuracy on validation set
# Validation loss is 0.026309304
# Epoch 169, Iteration 999, loss = 0.03118850
# Checking accuracy on validation set
# Validation loss is 0.026307551
# Epoch 170, Iteration 999, loss = 0.03118829
# Checking accuracy on validation set
# Validation loss is 0.026306791
# Epoch 171, Iteration 999, loss = 0.03118682
# Checking accuracy on validation set
# Validation loss is 0.02630693
# Epoch 172, Iteration 999, loss = 0.03118535
# Checking accuracy on validation set
# Validation loss is 0.026304685
# Epoch 173, Iteration 999, loss = 0.03118381
# Checking accuracy on validation set
# Validation loss is 0.026302006
# Epoch 174, Iteration 999, loss = 0.03118392
# Checking accuracy on validation set
# Validation loss is 0.026300406
# Epoch 175, Iteration 999, loss = 0.03118389
# Checking accuracy on validation set
# Validation loss is 0.026297856
# Epoch 176, Iteration 999, loss = 0.03118107
# Checking accuracy on validation set
# Validation loss is 0.026297435
# Epoch 177, Iteration 999, loss = 0.03117970
# Checking accuracy on validation set
# Validation loss is 0.026295982
# Epoch 178, Iteration 999, loss = 0.03117890
# Checking accuracy on validation set
# Validation loss is 0.02629768
# Epoch 179, Iteration 999, loss = 0.03117972
# Checking accuracy on validation set
# Validation loss is 0.026292253
# Epoch 180, Iteration 999, loss = 0.03117541
# Checking accuracy on validation set
# Validation loss is 0.026291063
# Epoch 181, Iteration 999, loss = 0.03117329
# Checking accuracy on validation set
# Validation loss is 0.026290545
# Epoch 182, Iteration 999, loss = 0.03117184
# Checking accuracy on validation set
# Validation loss is 0.026290307
# Epoch 183, Iteration 999, loss = 0.03117182
# Checking accuracy on validation set
# Validation loss is 0.02629299
# Epoch 184, Iteration 999, loss = 0.03117642
# Checking accuracy on validation set
# Validation loss is 0.026285706
# Epoch 185, Iteration 999, loss = 0.03117283
# Checking accuracy on validation set
# Validation loss is 0.026284924
# Epoch 186, Iteration 999, loss = 0.03116823
# Checking accuracy on validation set
# Validation loss is 0.026283266
# Epoch 187, Iteration 999, loss = 0.03116520
# Checking accuracy on validation set
# Validation loss is 0.026283892
# Epoch 188, Iteration 999, loss = 0.03116344
# Checking accuracy on validation set
# Validation loss is 0.026284518
# Epoch 189, Iteration 999, loss = 0.03116191
# Checking accuracy on validation set
# Validation loss is 0.026283214
# Epoch 190, Iteration 999, loss = 0.03116147
# Checking accuracy on validation set
# Validation loss is 0.026281048
# Epoch 191, Iteration 999, loss = 0.03115984
# Checking accuracy on validation set
# Validation loss is 0.026281638
# Epoch 192, Iteration 999, loss = 0.03115758
# Checking accuracy on validation set
# Validation loss is 0.026279852
# Epoch 193, Iteration 999, loss = 0.03115757
# Checking accuracy on validation set
# Validation loss is 0.026278539
# Epoch 194, Iteration 999, loss = 0.03115674
# Checking accuracy on validation set
# Validation loss is 0.026276108
# Epoch 195, Iteration 999, loss = 0.03115358
# Checking accuracy on validation set
# Validation loss is 0.026276067
# Epoch 196, Iteration 999, loss = 0.03115339
# Checking accuracy on validation set
# Validation loss is 0.026274402
# Epoch 197, Iteration 999, loss = 0.03115157
# Checking accuracy on validation set
# Validation loss is 0.026274798
# Epoch 198, Iteration 999, loss = 0.03114982
# Checking accuracy on validation set
# Validation loss is 0.026272714
# Epoch 199, Iteration 999, loss = 0.03114809
# Checking accuracy on validation set
# Validation loss is 0.026272336
# Epoch 200, Iteration 999, loss = 0.03114648
# Checking accuracy on validation set
# Validation loss is 0.026270462
# Epoch 201, Iteration 999, loss = 0.03114496
# Checking accuracy on validation set
# Validation loss is 0.026270315
# Epoch 202, Iteration 999, loss = 0.03114390
# Checking accuracy on validation set
# Validation loss is 0.026268981
# Epoch 203, Iteration 999, loss = 0.03114277
# Checking accuracy on validation set
# Validation loss is 0.02626764
# Epoch 204, Iteration 999, loss = 0.03114119
# Checking accuracy on validation set
# Validation loss is 0.0262667
# Epoch 205, Iteration 999, loss = 0.03115086
# Checking accuracy on validation set
# Validation loss is 0.026261259
# Epoch 206, Iteration 999, loss = 0.03114282
# Checking accuracy on validation set
# Validation loss is 0.02626064
# Epoch 207, Iteration 999, loss = 0.03113888
# Checking accuracy on validation set
# Validation loss is 0.026261332
# Epoch 208, Iteration 999, loss = 0.03113701
# Checking accuracy on validation set
# Validation loss is 0.02626125
# Epoch 209, Iteration 999, loss = 0.03113652
# Checking accuracy on validation set
# Validation loss is 0.026260845
# Epoch 210, Iteration 999, loss = 0.03113480
# Checking accuracy on validation set
# Validation loss is 0.026259309
# Epoch 211, Iteration 999, loss = 0.03113939
# Checking accuracy on validation set
# Validation loss is 0.026257508
# Epoch 212, Iteration 999, loss = 0.03113757
# Checking accuracy on validation set
# Validation loss is 0.026255498
# Epoch 213, Iteration 999, loss = 0.03113290
# Checking accuracy on validation set
# Validation loss is 0.02625606
# Epoch 214, Iteration 999, loss = 0.03113144
# Checking accuracy on validation set
# Validation loss is 0.026256332
# Epoch 215, Iteration 999, loss = 0.03112987
# Checking accuracy on validation set
# Validation loss is 0.026255837
# Epoch 216, Iteration 999, loss = 0.03112886
# Checking accuracy on validation set
# Validation loss is 0.026255365
# Epoch 217, Iteration 999, loss = 0.03112878
# Checking accuracy on validation set
# Validation loss is 0.026254002
# Epoch 218, Iteration 999, loss = 0.03112701
# Checking accuracy on validation set
# Validation loss is 0.026253434
# Epoch 219, Iteration 999, loss = 0.03112685
# Checking accuracy on validation set
# Validation loss is 0.026251696
# Epoch 220, Iteration 999, loss = 0.03112618
# Checking accuracy on validation set
# Validation loss is 0.026250662
# Epoch 221, Iteration 999, loss = 0.03112432
# Checking accuracy on validation set
# Validation loss is 0.02625048
# Epoch 222, Iteration 999, loss = 0.03112301
# Checking accuracy on validation set
# Validation loss is 0.026249895
# Epoch 223, Iteration 999, loss = 0.03112153
# Checking accuracy on validation set
# Validation loss is 0.026249573
# Epoch 224, Iteration 999, loss = 0.03112102
# Checking accuracy on validation set
# Validation loss is 0.02624845
# Epoch 225, Iteration 999, loss = 0.03112351
# Checking accuracy on validation set
# Validation loss is 0.026249947
# Epoch 226, Iteration 999, loss = 0.03113107
# Checking accuracy on validation set
# Validation loss is 0.026243024
# Epoch 227, Iteration 999, loss = 0.03112166
# Checking accuracy on validation set
# Validation loss is 0.02624313
# Epoch 228, Iteration 999, loss = 0.03111880
# Checking accuracy on validation set
# Validation loss is 0.026244273
# Epoch 229, Iteration 999, loss = 0.03111782
# Checking accuracy on validation set
# Validation loss is 0.026245033
# Epoch 230, Iteration 999, loss = 0.03111671
# Checking accuracy on validation set
# Validation loss is 0.026243953
# Epoch 231, Iteration 999, loss = 0.03111525
# Checking accuracy on validation set
# Validation loss is 0.026243942
# Epoch 232, Iteration 999, loss = 0.03111404
# Checking accuracy on validation set
# Validation loss is 0.026243545
# Epoch 233, Iteration 999, loss = 0.03111281
# Checking accuracy on validation set
# Validation loss is 0.026243236
# Epoch 234, Iteration 999, loss = 0.03111225
# Checking accuracy on validation set
# Validation loss is 0.026242966
# Epoch 235, Iteration 999, loss = 0.03111140
# Checking accuracy on validation set
# Validation loss is 0.026242414
# Epoch 236, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026240358
# Epoch 237, Iteration 999, loss = 0.03111183
# Checking accuracy on validation set
# Validation loss is 0.026239509
# Epoch 238, Iteration 999, loss = 0.03110920
# Checking accuracy on validation set
# Validation loss is 0.026240263
# Epoch 239, Iteration 999, loss = 0.03110961
# Checking accuracy on validation set
# Validation loss is 0.026239686
# Epoch 240, Iteration 999, loss = 0.03113947
# Checking accuracy on validation set
# Validation loss is 0.026207045
# Epoch 241, Iteration 999, loss = 0.03112802
# Checking accuracy on validation set
# Validation loss is 0.0261983
# Epoch 242, Iteration 999, loss = 0.03112477
# Checking accuracy on validation set
# Validation loss is 0.02619392
# Epoch 243, Iteration 999, loss = 0.03112243
# Checking accuracy on validation set
# Validation loss is 0.026191413
# Epoch 244, Iteration 999, loss = 0.03112124
# Checking accuracy on validation set
# Validation loss is 0.026189243
# Epoch 245, Iteration 999, loss = 0.03112017
# Checking accuracy on validation set
# Validation loss is 0.02618765
# Epoch 246, Iteration 999, loss = 0.03111946
# Checking accuracy on validation set
# Validation loss is 0.026189342
# Epoch 247, Iteration 999, loss = 0.03112004
# Checking accuracy on validation set
# Validation loss is 0.026183724
# Epoch 248, Iteration 999, loss = 0.03111858
# Checking accuracy on validation set
# Validation loss is 0.026182907
# Epoch 249, Iteration 999, loss = 0.03111777
# Checking accuracy on validation set
# Validation loss is 0.026182393
# Epoch 250, Iteration 999, loss = 0.03111692
# Checking accuracy on validation set
# Validation loss is 0.0261821
# Epoch 251, Iteration 999, loss = 0.03112485
# Checking accuracy on validation set
# Validation loss is 0.0261717
# Epoch 252, Iteration 999, loss = 0.03112061
# Checking accuracy on validation set
# Validation loss is 0.026167704
# Epoch 253, Iteration 999, loss = 0.03111910
# Checking accuracy on validation set
# Validation loss is 0.026166031
# Epoch 254, Iteration 999, loss = 0.03111842
# Checking accuracy on validation set
# Validation loss is 0.026164852
# Epoch 255, Iteration 999, loss = 0.03111799
# Checking accuracy on validation set
# Validation loss is 0.026164018
# Epoch 256, Iteration 999, loss = 0.03111769
# Checking accuracy on validation set
# Validation loss is 0.02616331
# Epoch 257, Iteration 999, loss = 0.03111744
# Checking accuracy on validation set
# Validation loss is 0.026162725
# Epoch 258, Iteration 999, loss = 0.03111725
# Checking accuracy on validation set
# Validation loss is 0.02616223
# Epoch 259, Iteration 999, loss = 0.03111708
# Checking accuracy on validation set
# Validation loss is 0.026161792
# Epoch 260, Iteration 999, loss = 0.03111693
# Checking accuracy on validation set
# Validation loss is 0.026161397
# Epoch 261, Iteration 999, loss = 0.03111679
# Checking accuracy on validation set
# Validation loss is 0.026161073
# Epoch 262, Iteration 999, loss = 0.03111650
# Checking accuracy on validation set
# Validation loss is 0.026160253
# Epoch 263, Iteration 999, loss = 0.03111630
# Checking accuracy on validation set
# Validation loss is 0.026159653
# Epoch 264, Iteration 999, loss = 0.03111618
# Checking accuracy on validation set
# Validation loss is 0.026159178
# Epoch 265, Iteration 999, loss = 0.03111609
# Checking accuracy on validation set
# Validation loss is 0.026158817
# Epoch 266, Iteration 999, loss = 0.03111603
# Checking accuracy on validation set
# Validation loss is 0.026158512
# Epoch 267, Iteration 999, loss = 0.03111599
# Checking accuracy on validation set
# Validation loss is 0.026158256
# Epoch 268, Iteration 999, loss = 0.03111595
# Checking accuracy on validation set
# Validation loss is 0.026158057
# Epoch 269, Iteration 999, loss = 0.03111591
# Checking accuracy on validation set
# Validation loss is 0.026157886
# Epoch 270, Iteration 999, loss = 0.03111588
# Checking accuracy on validation set
# Validation loss is 0.026157742
# Epoch 271, Iteration 999, loss = 0.03111586
# Checking accuracy on validation set
# Validation loss is 0.026157618
# Epoch 272, Iteration 999, loss = 0.03111584
# Checking accuracy on validation set
# Validation loss is 0.026157498
# Epoch 273, Iteration 999, loss = 0.03111572
# Checking accuracy on validation set
# Validation loss is 0.02615748
# Epoch 274, Iteration 999, loss = 0.03111572
# Checking accuracy on validation set
# Validation loss is 0.026157463
# Epoch 275, Iteration 999, loss = 0.03111571
# Checking accuracy on validation set
# Validation loss is 0.026157444
# Epoch 276, Iteration 999, loss = 0.03111571
# Checking accuracy on validation set
# Validation loss is 0.026157426
# Epoch 277, Iteration 999, loss = 0.03111571
# Checking accuracy on validation set
# Validation loss is 0.02615741
# Epoch 278, Iteration 999, loss = 0.03111571
# Checking accuracy on validation set
# Validation loss is 0.0261574
# Epoch 279, Iteration 999, loss = 0.03111570
# Checking accuracy on validation set
# Validation loss is 0.02615738
# Epoch 280, Iteration 999, loss = 0.03111570
# Checking accuracy on validation set
# Validation loss is 0.026157364
# Epoch 281, Iteration 999, loss = 0.03111570
# Checking accuracy on validation set
# Validation loss is 0.02615735
# Epoch 282, Iteration 999, loss = 0.03111570
# Checking accuracy on validation set
# Validation loss is 0.026157334
# Epoch 283, Iteration 999, loss = 0.03111570
# Checking accuracy on validation set
# Validation loss is 0.026157316
# Epoch 284, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157316
# Epoch 285, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157318
# Epoch 286, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157316
# Epoch 287, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157314
# Epoch 288, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157314
# Epoch 289, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157314
# Epoch 290, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157314
# Epoch 291, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 292, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 293, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 294, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 295, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 296, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 297, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157308
# Epoch 298, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157312
# Epoch 299, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615731
# Epoch 300, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157307
# Epoch 301, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157307
# Epoch 302, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157307
# Epoch 303, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157305
# Epoch 304, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157305
# Epoch 305, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157305
# Epoch 306, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157303
# Epoch 307, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157303
# Epoch 308, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.0261573
# Epoch 309, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.0261573
# Epoch 310, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157299
# Epoch 311, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157297
# Epoch 312, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157297
# Epoch 313, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157297
# Epoch 314, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157295
# Epoch 315, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157295
# Epoch 316, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157292
# Epoch 317, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615729
# Epoch 318, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157286
# Epoch 319, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615729
# Epoch 320, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157286
# Epoch 321, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157282
# Epoch 322, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615728
# Epoch 323, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615728
# Epoch 324, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615728
# Epoch 325, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615728
# Epoch 326, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157279
# Epoch 327, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615728
# Epoch 328, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157277
# Epoch 329, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 330, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157275
# Epoch 331, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157277
# Epoch 332, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157277
# Epoch 333, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 334, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 335, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 336, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 337, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157273
# Epoch 338, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615727
# Epoch 339, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.02615727
# Epoch 340, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157266
# Epoch 341, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157266
# Epoch 342, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157262
# Epoch 343, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157262
# Epoch 344, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157262
# Epoch 345, Iteration 999, loss = 0.03111568
# Checking accuracy on validation set
# Validation loss is 0.026157258
# Epoch 346, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157254
# Epoch 347, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157254
# Epoch 348, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157254
# Epoch 349, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615725
# Epoch 350, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615725
# Epoch 351, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615725
# Epoch 352, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157247
# Epoch 353, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157247
# Epoch 354, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157247
# Epoch 355, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 356, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157245
# Epoch 357, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157247
# Epoch 358, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 359, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615725
# Epoch 360, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 361, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 362, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 363, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157249
# Epoch 364, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157245
# Epoch 365, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157245
# Epoch 366, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157245
# Epoch 367, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157241
# Epoch 368, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157241
# Epoch 369, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157241
# Epoch 370, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157241
# Epoch 371, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 372, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 373, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 374, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 375, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 376, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 377, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157241
# Epoch 378, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157234
# Epoch 379, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 380, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157238
# Epoch 381, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157234
# Epoch 382, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615724
# Epoch 383, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157236
# Epoch 384, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157236
# Epoch 385, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157236
# Epoch 386, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157234
# Epoch 387, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157234
# Epoch 388, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157234
# Epoch 389, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157236
# Epoch 390, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615723
# Epoch 391, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157228
# Epoch 392, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157228
# Epoch 393, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157226
# Epoch 394, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157226
# Epoch 395, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157228
# Epoch 396, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157226
# Epoch 397, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157225
# Epoch 398, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157225
# Epoch 399, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615722
# Epoch 400, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615722
# Epoch 401, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157219
# Epoch 402, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157223
# Epoch 403, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157223
# Epoch 404, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615722
# Epoch 405, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615722
# Epoch 406, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615722
# Epoch 407, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157219
# Epoch 408, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157217
# Epoch 409, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157215
# Epoch 410, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157215
# Epoch 411, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157213
# Epoch 412, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157213
# Epoch 413, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157212
# Epoch 414, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 415, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 416, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157206
# Epoch 417, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 418, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 419, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 420, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.02615721
# Epoch 421, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157206
# Epoch 422, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157204
# Epoch 423, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157202
# Epoch 424, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.0261572
# Epoch 425, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.0261572
# Epoch 426, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157198
# Epoch 427, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157197
# Epoch 428, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157195
# Epoch 429, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157195
# Epoch 430, Iteration 999, loss = 0.03111567
# Checking accuracy on validation set
# Validation loss is 0.026157195
# Epoch 431, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157193
# Epoch 432, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157193
# Epoch 433, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157193
# Epoch 434, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157191
# Epoch 435, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615719
# Epoch 436, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157187
# Epoch 437, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157187
# Epoch 438, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157185
# Epoch 439, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157185
# Epoch 440, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157184
# Epoch 441, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157184
# Epoch 442, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157182
# Epoch 443, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615718
# Epoch 444, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615718
# Epoch 445, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157176
# Epoch 446, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157178
# Epoch 447, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157174
# Epoch 448, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157174
# Epoch 449, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157174
# Epoch 450, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157178
# Epoch 451, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157174
# Epoch 452, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157176
# Epoch 453, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157176
# Epoch 454, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157172
# Epoch 455, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157172
# Epoch 456, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157169
# Epoch 457, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157167
# Epoch 458, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157167
# Epoch 459, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157163
# Epoch 460, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157163
# Epoch 461, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157163
# Epoch 462, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615716
# Epoch 463, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615716
# Epoch 464, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615716
# Epoch 465, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615716
# Epoch 466, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615716
# Epoch 467, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157157
# Epoch 468, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 469, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157157
# Epoch 470, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 471, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157154
# Epoch 472, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 473, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 474, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 475, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 476, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 477, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 478, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157156
# Epoch 479, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 480, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157154
# Epoch 481, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 482, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157152
# Epoch 483, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157148
# Epoch 484, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157148
# Epoch 485, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157148
# Epoch 486, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157146
# Epoch 487, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157143
# Epoch 488, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.02615714
# Epoch 489, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157143
# Epoch 490, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157143
# Epoch 491, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157137
# Epoch 492, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157137
# Epoch 493, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157135
# Epoch 494, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157135
# Epoch 495, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157135
# Epoch 496, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157133
# Epoch 497, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157133
# Epoch 498, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157131
# Epoch 499, Iteration 999, loss = 0.03111566
# Checking accuracy on validation set
# Validation loss is 0.026157131

# %%
model_path= "./misc/model_lstm.pth"
torch.save(model.state_dict(),model_path)

# %%
model=LSTMNet(input_dim=160, hidden_dim=25, fclayer_dim=25, output_dim=160, num_layers=2,dropout_prob=0.1)
model.load_state_dict(torch.load(model_path))

# %%
dataset=DAPSDatasetHelper()
test_index=18869
model.to(device="cpu")
img_test,_= dataset.get_indxd_file(test_index)
img_label,_= dataset.get_indxd_file(test_index,True)
img = torch.tensor(img_test)
img= torch.permute(img,(1,0))
img=img.unsqueeze(0)
img=img.to(dtype=torch.float32)
model.eval()
with torch.no_grad():
    out=model(img*img)
out = out *img
out=out.squeeze(0)
out= torch.permute(out,(1,0))

# %%
plt.figure()
ax1=plt.subplot(1,3,1)
ax1.imshow(img_test)
ax1.title.set_text("input")
ax2=plt.subplot(1,3,2)
ax2.imshow(out.cpu().numpy())
ax2.title.set_text("output")
ax3=plt.subplot(1,3,3)
ax3.imshow(img_label)
ax3.title.set_text("GT")

# %%
plt.plot(train_loss)
plt.plot(val_loss)
plt.legend(["train loss","validation loss"])

# %% [markdown]
# Buffer level processing with 10ms of input samples being buffered and fed to the feature extractor in every iteration

# %%
dirpath_daps="../dataset_daps/daps/"
input,sr=librosa.load(dirpath_daps+'/ipad_balcony1/f1_script1_ipad_balcony1.wav',duration=30,sr=8000)
stftx=librosa.stft(input,n_fft=318,hop_length=80)
magstftx,phasex=librosa.magphase(stftx)
segments=stftx.shape[1]//32
specs=np.zeros_like(magstftx)
outs=[]
for i in range(0,segments):
    spec=magstftx[:,32*i:32*i+32]
    img = torch.tensor(spec)
    img= torch.permute(img,(1,0))
    img=img.unsqueeze(0)
    img=img.to(dtype=torch.float32)
    model.eval()
    with torch.no_grad():
        out=model(img*img)
    out=out.squeeze(0)
    out= torch.permute(out,(1,0))
    out=out.numpy()*spec
    outs.append(out)
    specs[:,32*i:32*i+32]=out*spec

specs=np.array(specs)
print(np.max(specs))

reconst=specs*phasex

plt.figure()
plt.imshow(magstftx)

plt.figure()
plt.imshow(specs)

print(stftx.shape)

istftx=librosa.istft(stftx,hop_length=80,n_fft=318)
reistftx=(1/80)*librosa.istft(reconst,hop_length=80,n_fft=318)
# Out:
# 702.9197
# (160, 3001)

# %%
wav.write("./input.wav", 8000, input)
wav.write("./reconstructed.wav", 8000, reistftx)

# %%
class AdaptiveFilters():
    def __init__(self,mu,taps):
        self.e=0
        self.w=np.zeros((taps,1))
        self.xd=np.zeros((taps,1))
        self.mu=mu
        self.N=taps

# %%
class NLMS(AdaptiveFilters):
    #initialize
    def __init__(self,mu,taps):
        super().__init__(mu,taps)
        self.mu=mu
        self.N=taps
        self.e=0
        self.w=np.zeros((taps,1))
        self.xd=np.zeros((taps,1))

    #updates the filter sample by sample and updates weights sample by sample
    def run(self,x,d):
        N=self.N
        #udpate delay line 
        self.xd[0]=x
        #compute filter output
        y = np.dot(self.w.T,self.xd)
        #compute input energy
        pw=np.linalg.norm(self.xd)
        pw=pw*pw
        #pw=pw*pw
        #calculate error
        e = d - y
        self.e=e

        #normalize by input energy
        e= e/(pw+0.0000000001)
        #compute gradients
        Fw=self.mu*np.multiply(self.xd,e)
        
        Fw=Fw.reshape(Fw.shape[0],-1)
        #weight update
        self.w = self.w + Fw
    
        #filtered output post update
        y = np.dot(self.w.T,self.xd)
        #shift delay line
        self.xd[1:]=self.xd[:-1]
 
        #return current output sample, current error sample and current weights
        return (y,self.e,self.w)

# %%
d,sr= librosa.load('../dataset/AEC-Challenge/datasets/synthetic/nearend_mic_signal/nearend_mic_fileid_10.wav',sr=8000)
x,sr=librosa.load('../dataset/AEC-Challenge/datasets/synthetic/farend_speech/farend_speech_fileid_10.wav',sr=8000)
echo,sr=librosa.load('../dataset/AEC-Challenge/datasets/synthetic/echo_signal/echo_fileid_10.wav',sr=8000)
near_end,sr= librosa.load('../dataset/AEC-Challenge/datasets/synthetic/nearend_speech/nearend_speech_fileid_10.wav',sr=8000)

# %%
input=d
stftx=librosa.stft(input,n_fft=318,hop_length=80)
magstftx,phasex=librosa.magphase(stftx)
segments=stftx.shape[1]//32
specs=np.zeros_like(magstftx)
outs=[]
for i in range(0,segments+1):
    spec=magstftx[:,32*i:32*i+32]
    img = torch.tensor(spec)
    img= torch.permute(img,(1,0))
    img=img.unsqueeze(0)
    img=img.to(dtype=torch.float32)
    model.eval()
    with torch.no_grad():
        out=model(img*img)
    out=out.squeeze(0)  
    out= torch.permute(out,(1,0))
    out=out.numpy()*spec
    outs.append(out)
    specs[:,32*i:32*i+32]=out*spec

specs=np.array(specs)/np.max(specs)

reconst=specs*phasex

plt.figure()
plt.imshow(magstftx)

plt.figure()
plt.imshow(specs)

print(stftx.shape)

istftx=librosa.istft(stftx,hop_length=80,n_fft=318)
reistftx=librosa.istft(reconst,hop_length=80,n_fft=318)
reistftx=librosa.util.normalize(reistftx)
# Out:
# (160, 1001)

# %%
#test wrapper for NLMS filter on aec data for single talk case
taps=1024
lmscls= NLMS(0.05,taps)
w=np.zeros((taps,1))
y=np.zeros_like(x)
e=np.zeros_like(x)
x1=librosa.util.normalize(x)
d1=librosa.util.normalize(d)
for i in range(0,len(x)):
    (y[i],e[i],w2)=lmscls.run(x1[i],d1[i])

# %%
#test wrapper for NLMS filter on aec data for single talk case
taps=1024
lmscls= NLMS(0.05,taps)
w1=np.zeros((taps,1))
y1=np.zeros_like(x)
e1=np.zeros_like(x)
for i in range(0,len(reistftx)):
    (y1[i],e1[i],w3)=lmscls.run(x1[i],reistftx[i])

# %%
plt.figure()
plt.plot(e)
plt.title("recovered near end")
plt.figure()
plt.plot(e1)
plt.title("recovered near end after pre filtering")
plt.figure()
plt.plot(y1)
plt.title("estimated echo")
plt.figure()
plt.plot(reistftx)
plt.title("desired signal")
plt.figure()
plt.plot(x1)
plt.title("far end reference(input signal)")
plt.figure()
plt.plot(near_end)
plt.title("near end signal")
# Out:
# Text(0.5, 1.0, 'near end signal')
